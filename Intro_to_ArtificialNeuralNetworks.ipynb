# %% [markdown]
# Implementation of single LTU network using Perceptron class

# %%
import numpy as np
from sklearn.datasets import load_iris
from sklearn.linear_model import Perceptron

# %%
iris = load_iris()
x = iris.data[:, (2,3)]
y = (iris.target == 0).astype(np.int)

# %%
percep_clf = Perceptron()
percep_clf.fit(x, y)
# Out:
# C:\Users\manog\Anaconda3\lib\site-packages\sklearn\linear_model\stochastic_gradient.py:128: FutureWarning: max_iter and tol parameters have been added in <class 'sklearn.linear_model.perceptron.Perceptron'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   "and default tol will be 1e-3." % type(self), FutureWarning)
# Perceptron(alpha=0.0001, class_weight=None, eta0=1.0, fit_intercept=True,
#       max_iter=None, n_iter=None, n_jobs=1, penalty=None, random_state=0,
#       shuffle=True, tol=None, verbose=0, warm_start=False)

# %%
y_pred = percep_clf.predict([[2, 0.5]])

# %% [markdown]
# Training a DNN using TensorFlow API

# %%
import tensorflow as tf

# %%
(X_train, y_train), (X_test, y_test) = tf.keras.datasets.mnist.load_data()
X_train = X_train.astype(np.float32).reshape(-1, 28*28) / 255.0
X_test = X_test.astype(np.float32).reshape(-1, 28*28) / 255.0
y_train = y_train.astype(np.int32)
y_test = y_test.astype(np.int32)
X_valid, X_train = X_train[:5000], X_train[5000:]
y_valid, y_train = y_train[:5000], y_train[5000:]

# %% [markdown]
# Here, we have taken MNIST dataset and split the data into training and testing sets.

# %% [markdown]
# Now, we will train a DNN for classification with two hidden layers (one with 300 neurons, and the other with 100 neurons) and a softmax output layer with 10 neurons.

# %%
feature_cols = [tf.feature_column.numeric_column("X", shape = [28*28])]
dnn_clf = tf.estimator.DNNClassifier(hidden_units = [300,100], n_classes = 10, feature_columns = feature_cols)
input_fn = tf.estimator.inputs.numpy_input_fn(x = {"X": X_train}, y = y_train, num_epochs = 40, batch_size = 50, shuffle = True)
dnn_clf.train(input_fn = input_fn)
# Out:
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: C:\Users\manog\AppData\Local\Temp\tmps050b1z7
# INFO:tensorflow:Using config: {'_model_dir': 'C:\\Users\\manog\\AppData\\Local\\Temp\\tmps050b1z7', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x0000016268AD2748>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# WARNING:tensorflow:From C:\Users\manog\Anaconda3\lib\site-packages\tensorflow\python\framework\op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From C:\Users\manog\Anaconda3\lib\site-packages\tensorflow_estimator\python\estimator\inputs\queues\feeding_queue_runner.py:62: QueueRunner.__init__ (from tensorflow.python.training.queue_runner_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# To construct input pipelines, use the `tf.data` module.
# WARNING:tensorflow:From C:\Users\manog\Anaconda3\lib\site-packages\tensorflow_estimator\python\estimator\inputs\queues\feeding_functions.py:500: add_queue_runner (from tensorflow.python.training.queue_runner_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# To construct input pipelines, use the `tf.data` module.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:From C:\Users\manog\Anaconda3\lib\site-packages\tensorflow\python\feature_column\feature_column_v2.py:2703: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# WARNING:tensorflow:From C:\Users\manog\Anaconda3\lib\site-packages\tensorflow\python\training\monitored_session.py:809: start_queue_runners (from tensorflow.python.training.queue_runner_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# To construct input pipelines, use the `tf.data` module.
# INFO:tensorflow:Saving checkpoints for 0 into C:\Users\manog\AppData\Local\Temp\tmps050b1z7\model.ckpt.
# INFO:tensorflow:loss = 117.829735, step = 1
# INFO:tensorflow:global_step/sec: 218.905
# INFO:tensorflow:loss = 14.849935, step = 101 (0.458 sec)
# INFO:tensorflow:global_step/sec: 262.883
# INFO:tensorflow:loss = 11.865437, step = 201 (0.380 sec)
# INFO:tensorflow:global_step/sec: 265.27
# INFO:tensorflow:loss = 10.428271, step = 301 (0.378 sec)
# INFO:tensorflow:global_step/sec: 275.817
# INFO:tensorflow:loss = 9.283643, step = 401 (0.362 sec)
# INFO:tensorflow:global_step/sec: 280.018
# INFO:tensorflow:loss = 9.389841, step = 501 (0.357 sec)
# INFO:tensorflow:global_step/sec: 284.362
# INFO:tensorflow:loss = 10.227964, step = 601 (0.352 sec)
# INFO:tensorflow:global_step/sec: 282.372
# INFO:tensorflow:loss = 8.372933, step = 701 (0.355 sec)
# INFO:tensorflow:global_step/sec: 278.856
# INFO:tensorflow:loss = 5.2559404, step = 801 (0.359 sec)
# INFO:tensorflow:global_step/sec: 263.892
# INFO:tensorflow:loss = 2.183076, step = 901 (0.379 sec)
# INFO:tensorflow:global_step/sec: 283.563
# INFO:tensorflow:loss = 14.955045, step = 1001 (0.352 sec)
# INFO:tensorflow:global_step/sec: 270.622
# INFO:tensorflow:loss = 1.1169945, step = 1101 (0.372 sec)
# INFO:tensorflow:global_step/sec: 270.259
# INFO:tensorflow:loss = 4.8483443, step = 1201 (0.369 sec)
# INFO:tensorflow:global_step/sec: 277.703
# INFO:tensorflow:loss = 4.990543, step = 1301 (0.360 sec)
# INFO:tensorflow:global_step/sec: 280.408
# INFO:tensorflow:loss = 6.0308046, step = 1401 (0.357 sec)
# INFO:tensorflow:global_step/sec: 271.351
# INFO:tensorflow:loss = 0.5169477, step = 1501 (0.369 sec)
# INFO:tensorflow:global_step/sec: 252.016
# INFO:tensorflow:loss = 16.193552, step = 1601 (0.397 sec)
# INFO:tensorflow:global_step/sec: 256.831
# INFO:tensorflow:loss = 1.3773607, step = 1701 (0.389 sec)
# INFO:tensorflow:global_step/sec: 273.559
# INFO:tensorflow:loss = 3.6614974, step = 1801 (0.366 sec)
# INFO:tensorflow:global_step/sec: 264.933
# INFO:tensorflow:loss = 7.853599, step = 1901 (0.376 sec)
# INFO:tensorflow:global_step/sec: 268.817
# INFO:tensorflow:loss = 8.229384, step = 2001 (0.373 sec)
# INFO:tensorflow:global_step/sec: 271.716
# INFO:tensorflow:loss = 1.3844181, step = 2101 (0.367 sec)
# INFO:tensorflow:global_step/sec: 286.38
# INFO:tensorflow:loss = 11.746277, step = 2201 (0.349 sec)
# INFO:tensorflow:global_step/sec: 283.563
# INFO:tensorflow:loss = 0.9364128, step = 2301 (0.353 sec)
# INFO:tensorflow:global_step/sec: 278.472
# INFO:tensorflow:loss = 7.2691617, step = 2401 (0.359 sec)
# INFO:tensorflow:global_step/sec: 274.677
# INFO:tensorflow:loss = 2.050264, step = 2501 (0.364 sec)
# INFO:tensorflow:global_step/sec: 262.859
# INFO:tensorflow:loss = 2.5762596, step = 2601 (0.380 sec)
# INFO:tensorflow:global_step/sec: 275.804
# INFO:tensorflow:loss = 1.0515748, step = 2701 (0.363 sec)
# INFO:tensorflow:global_step/sec: 279.631
# INFO:tensorflow:loss = 0.61036724, step = 2801 (0.357 sec)
# INFO:tensorflow:global_step/sec: 279.629
# INFO:tensorflow:loss = 2.1125078, step = 2901 (0.359 sec)
# INFO:tensorflow:global_step/sec: 287.609
# INFO:tensorflow:loss = 2.359157, step = 3001 (0.347 sec)
# INFO:tensorflow:global_step/sec: 286.776
# INFO:tensorflow:loss = 2.4055443, step = 3101 (0.349 sec)
# INFO:tensorflow:global_step/sec: 303.191
# INFO:tensorflow:loss = 3.237386, step = 3201 (0.329 sec)
# INFO:tensorflow:global_step/sec: 290.929
# INFO:tensorflow:loss = 0.44104573, step = 3301 (0.345 sec)
# INFO:tensorflow:global_step/sec: 289.929
# INFO:tensorflow:loss = 0.15095997, step = 3401 (0.344 sec)
# INFO:tensorflow:global_step/sec: 292.279
# INFO:tensorflow:loss = 0.34717372, step = 3501 (0.342 sec)
# INFO:tensorflow:global_step/sec: 294.835
# INFO:tensorflow:loss = 3.7408864, step = 3601 (0.339 sec)
# INFO:tensorflow:global_step/sec: 293.04
# INFO:tensorflow:loss = 2.383793, step = 3701 (0.342 sec)
# INFO:tensorflow:global_step/sec: 283.564
# INFO:tensorflow:loss = 0.54191256, step = 3801 (0.351 sec)
# INFO:tensorflow:global_step/sec: 300.02
# INFO:tensorflow:loss = 0.21669091, step = 3901 (0.333 sec)
# INFO:tensorflow:global_step/sec: 298.244
# INFO:tensorflow:loss = 1.3681977, step = 4001 (0.336 sec)
# INFO:tensorflow:global_step/sec: 288.429
# INFO:tensorflow:loss = 1.1858044, step = 4101 (0.347 sec)
# INFO:tensorflow:global_step/sec: 293.898
# INFO:tensorflow:loss = 0.424552, step = 4201 (0.340 sec)
# INFO:tensorflow:global_step/sec: 307.806
# INFO:tensorflow:loss = 2.653702, step = 4301 (0.325 sec)
# INFO:tensorflow:global_step/sec: 279.243
# INFO:tensorflow:loss = 0.79615295, step = 4401 (0.358 sec)
# INFO:tensorflow:global_step/sec: 275.053
# INFO:tensorflow:loss = 1.4410228, step = 4501 (0.364 sec)
# INFO:tensorflow:global_step/sec: 300.017
# INFO:tensorflow:loss = 1.898197, step = 4601 (0.333 sec)
# INFO:tensorflow:global_step/sec: 276.943
# INFO:tensorflow:loss = 0.16762136, step = 4701 (0.361 sec)
# INFO:tensorflow:global_step/sec: 281.582
# INFO:tensorflow:loss = 0.27723336, step = 4801 (0.355 sec)
# INFO:tensorflow:global_step/sec: 283.563
# INFO:tensorflow:loss = 0.52332073, step = 4901 (0.352 sec)
# INFO:tensorflow:global_step/sec: 285.166
# INFO:tensorflow:loss = 0.32307404, step = 5001 (0.351 sec)
# INFO:tensorflow:global_step/sec: 298.685
# INFO:tensorflow:loss = 4.3158937, step = 5101 (0.335 sec)
# INFO:tensorflow:global_step/sec: 280.764
# INFO:tensorflow:loss = 1.2243855, step = 5201 (0.357 sec)
# INFO:tensorflow:global_step/sec: 288.85
# INFO:tensorflow:loss = 5.1081114, step = 5301 (0.344 sec)
# INFO:tensorflow:global_step/sec: 314.077
# INFO:tensorflow:loss = 2.9387155, step = 5401 (0.319 sec)
# INFO:tensorflow:global_step/sec: 279.629
# INFO:tensorflow:loss = 1.133555, step = 5501 (0.357 sec)
# INFO:tensorflow:global_step/sec: 277.705
# INFO:tensorflow:loss = 0.35938102, step = 5601 (0.361 sec)
# INFO:tensorflow:global_step/sec: 267.391
# INFO:tensorflow:loss = 6.7884827, step = 5701 (0.374 sec)
# INFO:tensorflow:global_step/sec: 275.427
# INFO:tensorflow:loss = 0.281543, step = 5801 (0.363 sec)
# INFO:tensorflow:global_step/sec: 276.563
# INFO:tensorflow:loss = 3.821343, step = 5901 (0.362 sec)
# INFO:tensorflow:global_step/sec: 276.091
# INFO:tensorflow:loss = 2.2740083, step = 6001 (0.362 sec)
# INFO:tensorflow:global_step/sec: 280.112
# INFO:tensorflow:loss = 0.26894513, step = 6101 (0.357 sec)
# INFO:tensorflow:global_step/sec: 277.322
# INFO:tensorflow:loss = 1.0954212, step = 6201 (0.361 sec)
# INFO:tensorflow:global_step/sec: 277.652
# INFO:tensorflow:loss = 4.882656, step = 6301 (0.360 sec)
# INFO:tensorflow:global_step/sec: 277.753
# INFO:tensorflow:loss = 4.1987433, step = 6401 (0.360 sec)
# INFO:tensorflow:global_step/sec: 277.706
# INFO:tensorflow:loss = 0.16620187, step = 6501 (0.360 sec)
# INFO:tensorflow:global_step/sec: 272.082
# INFO:tensorflow:loss = 3.1728377, step = 6601 (0.368 sec)
# INFO:tensorflow:global_step/sec: 274.679
# INFO:tensorflow:loss = 1.6635697, step = 6701 (0.365 sec)
# INFO:tensorflow:global_step/sec: 274.303
# INFO:tensorflow:loss = 2.525918, step = 6801 (0.364 sec)
# INFO:tensorflow:global_step/sec: 282.372
# INFO:tensorflow:loss = 0.26932722, step = 6901 (0.354 sec)
# INFO:tensorflow:global_step/sec: 276.941
# INFO:tensorflow:loss = 9.120327, step = 7001 (0.361 sec)
# INFO:tensorflow:global_step/sec: 275.426
# INFO:tensorflow:loss = 0.38154167, step = 7101 (0.363 sec)
# INFO:tensorflow:global_step/sec: 274.933
# INFO:tensorflow:loss = 0.46084833, step = 7201 (0.364 sec)
# INFO:tensorflow:global_step/sec: 278.209
# INFO:tensorflow:loss = 0.22492185, step = 7301 (0.360 sec)
# INFO:tensorflow:global_step/sec: 276.56
# INFO:tensorflow:loss = 0.015170648, step = 7401 (0.362 sec)
# INFO:tensorflow:global_step/sec: 275.805
# INFO:tensorflow:loss = 0.040057953, step = 7501 (0.363 sec)
# INFO:tensorflow:global_step/sec: 273.931
# INFO:tensorflow:loss = 0.13245131, step = 7601 (0.365 sec)
# INFO:tensorflow:global_step/sec: 277.704
# INFO:tensorflow:loss = 0.08120088, step = 7701 (0.360 sec)
# INFO:tensorflow:global_step/sec: 277.704
# INFO:tensorflow:loss = 0.1827352, step = 7801 (0.360 sec)
# INFO:tensorflow:global_step/sec: 278.471
# INFO:tensorflow:loss = 0.09306526, step = 7901 (0.359 sec)
# INFO:tensorflow:global_step/sec: 280.018
# INFO:tensorflow:loss = 2.5426443, step = 8001 (0.357 sec)
# INFO:tensorflow:global_step/sec: 276.183
# INFO:tensorflow:loss = 0.11657915, step = 8101 (0.362 sec)
# INFO:tensorflow:global_step/sec: 274.676
# INFO:tensorflow:loss = 1.4359894, step = 8201 (0.364 sec)
# INFO:tensorflow:global_step/sec: 275.428
# INFO:tensorflow:loss = 0.2744452, step = 8301 (0.364 sec)
# INFO:tensorflow:global_step/sec: 276.561
# INFO:tensorflow:loss = 0.11982968, step = 8401 (0.362 sec)
# INFO:tensorflow:global_step/sec: 274.303
# INFO:tensorflow:loss = 1.248089, step = 8501 (0.364 sec)
# INFO:tensorflow:global_step/sec: 274.677
# INFO:tensorflow:loss = 0.86704963, step = 8601 (0.364 sec)
# INFO:tensorflow:global_step/sec: 277.704
# INFO:tensorflow:loss = 1.339854, step = 8701 (0.361 sec)
# INFO:tensorflow:global_step/sec: 275.805
# INFO:tensorflow:loss = 0.6606058, step = 8801 (0.362 sec)
# INFO:tensorflow:global_step/sec: 277.704
# INFO:tensorflow:loss = 0.13318245, step = 8901 (0.360 sec)
# INFO:tensorflow:global_step/sec: 278.47
# INFO:tensorflow:loss = 2.729748, step = 9001 (0.359 sec)
# INFO:tensorflow:global_step/sec: 275.804
# INFO:tensorflow:loss = 0.7677999, step = 9101 (0.363 sec)
# INFO:tensorflow:global_step/sec: 278.088
# INFO:tensorflow:loss = 0.32432064, step = 9201 (0.360 sec)
# INFO:tensorflow:global_step/sec: 279.628
# INFO:tensorflow:loss = 1.3275908, step = 9301 (0.358 sec)
# INFO:tensorflow:global_step/sec: 278.472
# INFO:tensorflow:loss = 0.51474845, step = 9401 (0.359 sec)
# INFO:tensorflow:global_step/sec: 277.321
# INFO:tensorflow:loss = 1.1598833, step = 9501 (0.362 sec)
# INFO:tensorflow:global_step/sec: 276.558
# INFO:tensorflow:loss = 1.1060843, step = 9601 (0.362 sec)
# INFO:tensorflow:global_step/sec: 278.091
# INFO:tensorflow:loss = 0.5842093, step = 9701 (0.359 sec)
# INFO:tensorflow:global_step/sec: 278.855
# INFO:tensorflow:loss = 1.9940017, step = 9801 (0.359 sec)
# INFO:tensorflow:global_step/sec: 275.052
# INFO:tensorflow:loss = 0.28543827, step = 9901 (0.364 sec)
# INFO:tensorflow:global_step/sec: 275.428
# INFO:tensorflow:loss = 0.015327938, step = 10001 (0.363 sec)
# INFO:tensorflow:global_step/sec: 276.182
# INFO:tensorflow:loss = 1.0041202, step = 10101 (0.362 sec)
# INFO:tensorflow:global_step/sec: 267.037
# INFO:tensorflow:loss = 0.047704298, step = 10201 (0.374 sec)
# INFO:tensorflow:global_step/sec: 288.019
# INFO:tensorflow:loss = 0.5866387, step = 10301 (0.348 sec)
# INFO:tensorflow:global_step/sec: 279.63
# INFO:tensorflow:loss = 0.18634787, step = 10401 (0.357 sec)
# INFO:tensorflow:global_step/sec: 279.518
# INFO:tensorflow:loss = 0.21339262, step = 10501 (0.358 sec)
# INFO:tensorflow:global_step/sec: 275.16
# INFO:tensorflow:loss = 0.92280143, step = 10601 (0.364 sec)
# INFO:tensorflow:global_step/sec: 291.769
# INFO:tensorflow:loss = 0.0095237335, step = 10701 (0.343 sec)
# INFO:tensorflow:global_step/sec: 277.324
# INFO:tensorflow:loss = 0.3531263, step = 10801 (0.361 sec)
# INFO:tensorflow:global_step/sec: 276.561
# INFO:tensorflow:loss = 0.049777947, step = 10901 (0.362 sec)
# INFO:tensorflow:global_step/sec: 277.704
# INFO:tensorflow:loss = 0.07541136, step = 11001 (0.360 sec)
# INFO:tensorflow:global_step/sec: 288.019
# INFO:tensorflow:loss = 0.036116537, step = 11101 (0.348 sec)
# INFO:tensorflow:global_step/sec: 283.562
# INFO:tensorflow:loss = 1.2739761, step = 11201 (0.352 sec)
# INFO:tensorflow:global_step/sec: 273.932
# INFO:tensorflow:loss = 0.54658896, step = 11301 (0.365 sec)
# INFO:tensorflow:global_step/sec: 298.685
# INFO:tensorflow:loss = 0.2922169, step = 11401 (0.335 sec)
# INFO:tensorflow:global_step/sec: 277.323
# INFO:tensorflow:loss = 0.7873529, step = 11501 (0.361 sec)
# INFO:tensorflow:global_step/sec: 280.018
# INFO:tensorflow:loss = 0.2560498, step = 11601 (0.358 sec)
# INFO:tensorflow:global_step/sec: 288.718
# INFO:tensorflow:loss = 0.13067186, step = 11701 (0.346 sec)
# INFO:tensorflow:global_step/sec: 282.889
# INFO:tensorflow:loss = 0.70664054, step = 11801 (0.354 sec)
# INFO:tensorflow:global_step/sec: 287.607
# INFO:tensorflow:loss = 0.0775668, step = 11901 (0.348 sec)
# INFO:tensorflow:global_step/sec: 290.091
# INFO:tensorflow:loss = 0.073501065, step = 12001 (0.345 sec)
# INFO:tensorflow:global_step/sec: 279.243
# INFO:tensorflow:loss = 0.951503, step = 12101 (0.359 sec)
# INFO:tensorflow:global_step/sec: 282.766
# INFO:tensorflow:loss = 0.018607486, step = 12201 (0.353 sec)
# INFO:tensorflow:global_step/sec: 303.634
# INFO:tensorflow:loss = 0.18486933, step = 12301 (0.330 sec)
# INFO:tensorflow:global_step/sec: 284.364
# INFO:tensorflow:loss = 0.16287008, step = 12401 (0.352 sec)
# INFO:tensorflow:global_step/sec: 284.362
# INFO:tensorflow:loss = 0.059386633, step = 12501 (0.351 sec)
# INFO:tensorflow:global_step/sec: 279.242
# INFO:tensorflow:loss = 0.1577921, step = 12601 (0.358 sec)
# INFO:tensorflow:global_step/sec: 275.804
# INFO:tensorflow:loss = 0.4665129, step = 12701 (0.363 sec)
# INFO:tensorflow:global_step/sec: 275.804
# INFO:tensorflow:loss = 0.24903497, step = 12801 (0.363 sec)
# INFO:tensorflow:global_step/sec: 284.364
# INFO:tensorflow:loss = 0.05436762, step = 12901 (0.352 sec)
# INFO:tensorflow:global_step/sec: 284.362
# INFO:tensorflow:loss = 0.13127306, step = 13001 (0.351 sec)
# INFO:tensorflow:global_step/sec: 285.975
# INFO:tensorflow:loss = 0.14160955, step = 13101 (0.350 sec)
# INFO:tensorflow:global_step/sec: 298.688
# INFO:tensorflow:loss = 0.0397828, step = 13201 (0.335 sec)
# INFO:tensorflow:global_step/sec: 281.581
# INFO:tensorflow:loss = 0.1267475, step = 13301 (0.355 sec)
# INFO:tensorflow:global_step/sec: 285.167
# INFO:tensorflow:loss = 0.055604912, step = 13401 (0.351 sec)
# INFO:tensorflow:global_step/sec: 277.704
# INFO:tensorflow:loss = 0.08713293, step = 13501 (0.360 sec)
# INFO:tensorflow:global_step/sec: 276.183
# INFO:tensorflow:loss = 0.01145824, step = 13601 (0.362 sec)
# INFO:tensorflow:global_step/sec: 275.804
# INFO:tensorflow:loss = 0.020249365, step = 13701 (0.362 sec)
# INFO:tensorflow:global_step/sec: 275.805
# INFO:tensorflow:loss = 0.16038454, step = 13801 (0.363 sec)
# INFO:tensorflow:global_step/sec: 276.182
# INFO:tensorflow:loss = 0.16520247, step = 13901 (0.362 sec)
# INFO:tensorflow:global_step/sec: 274.677
# INFO:tensorflow:loss = 0.26072243, step = 14001 (0.365 sec)
# INFO:tensorflow:global_step/sec: 275.428
# INFO:tensorflow:loss = 0.12963904, step = 14101 (0.363 sec)
# INFO:tensorflow:global_step/sec: 275.051
# INFO:tensorflow:loss = 0.084393926, step = 14201 (0.364 sec)
# INFO:tensorflow:global_step/sec: 279.631
# INFO:tensorflow:loss = 0.022450002, step = 14301 (0.358 sec)
# INFO:tensorflow:global_step/sec: 276.94
# INFO:tensorflow:loss = 0.22454497, step = 14401 (0.361 sec)
# INFO:tensorflow:global_step/sec: 275.429
# INFO:tensorflow:loss = 0.065046296, step = 14501 (0.363 sec)
# INFO:tensorflow:global_step/sec: 276.941
# INFO:tensorflow:loss = 0.17295146, step = 14601 (0.362 sec)
# INFO:tensorflow:global_step/sec: 278.086
# INFO:tensorflow:loss = 0.16891904, step = 14701 (0.359 sec)
# INFO:tensorflow:global_step/sec: 278.088
# INFO:tensorflow:loss = 0.22801381, step = 14801 (0.360 sec)
# INFO:tensorflow:global_step/sec: 276.936
# INFO:tensorflow:loss = 0.009615723, step = 14901 (0.361 sec)
# INFO:tensorflow:global_step/sec: 275.432
# INFO:tensorflow:loss = 0.050565954, step = 15001 (0.363 sec)
# INFO:tensorflow:global_step/sec: 279.242
# INFO:tensorflow:loss = 0.05696412, step = 15101 (0.358 sec)
# INFO:tensorflow:global_step/sec: 274.677
# INFO:tensorflow:loss = 0.15009922, step = 15201 (0.364 sec)
# INFO:tensorflow:global_step/sec: 277.322
# INFO:tensorflow:loss = 0.32669768, step = 15301 (0.361 sec)
# INFO:tensorflow:global_step/sec: 276.182
# INFO:tensorflow:loss = 0.11857804, step = 15401 (0.363 sec)
# INFO:tensorflow:global_step/sec: 276.941
# INFO:tensorflow:loss = 0.0053363945, step = 15501 (0.361 sec)
# INFO:tensorflow:global_step/sec: 269.537
# INFO:tensorflow:loss = 0.21452741, step = 15601 (0.371 sec)
# INFO:tensorflow:global_step/sec: 271.349
# INFO:tensorflow:loss = 0.12309542, step = 15701 (0.368 sec)
# INFO:tensorflow:global_step/sec: 265.63
# INFO:tensorflow:loss = 0.46040848, step = 15801 (0.377 sec)
# INFO:tensorflow:global_step/sec: 275.806
# INFO:tensorflow:loss = 0.06757149, step = 15901 (0.363 sec)
# INFO:tensorflow:global_step/sec: 273.559
# INFO:tensorflow:loss = 0.037290394, step = 16001 (0.365 sec)
# INFO:tensorflow:global_step/sec: 276.94
# INFO:tensorflow:loss = 0.04019111, step = 16101 (0.361 sec)
# INFO:tensorflow:global_step/sec: 279.243
# INFO:tensorflow:loss = 0.06765488, step = 16201 (0.358 sec)
# INFO:tensorflow:global_step/sec: 275.804
# INFO:tensorflow:loss = 0.07720041, step = 16301 (0.363 sec)
# INFO:tensorflow:global_step/sec: 280.02
# INFO:tensorflow:loss = 0.11248393, step = 16401 (0.357 sec)
# INFO:tensorflow:global_step/sec: 276.56
# INFO:tensorflow:loss = 0.110920526, step = 16501 (0.362 sec)
# INFO:tensorflow:global_step/sec: 281.164
# INFO:tensorflow:loss = 0.13895464, step = 16601 (0.355 sec)
# INFO:tensorflow:global_step/sec: 274.702
# INFO:tensorflow:loss = 0.002957507, step = 16701 (0.364 sec)
# INFO:tensorflow:global_step/sec: 275.427
# INFO:tensorflow:loss = 0.058357537, step = 16801 (0.363 sec)
# INFO:tensorflow:global_step/sec: 275.805
# INFO:tensorflow:loss = 0.22632231, step = 16901 (0.363 sec)
# INFO:tensorflow:global_step/sec: 284.363
# INFO:tensorflow:loss = 0.043487057, step = 17001 (0.352 sec)
# INFO:tensorflow:global_step/sec: 274.677
# INFO:tensorflow:loss = 0.025219187, step = 17101 (0.364 sec)
# INFO:tensorflow:global_step/sec: 274.677
# INFO:tensorflow:loss = 0.0107885115, step = 17201 (0.364 sec)
# INFO:tensorflow:global_step/sec: 277.704
# INFO:tensorflow:loss = 0.11434166, step = 17301 (0.361 sec)
# INFO:tensorflow:global_step/sec: 275.805
# INFO:tensorflow:loss = 0.03861992, step = 17401 (0.362 sec)
# INFO:tensorflow:global_step/sec: 278.471
# INFO:tensorflow:loss = 0.40999752, step = 17501 (0.359 sec)
# INFO:tensorflow:global_step/sec: 285.395
# INFO:tensorflow:loss = 0.05572516, step = 17601 (0.350 sec)
# INFO:tensorflow:global_step/sec: 275.967
# INFO:tensorflow:loss = 0.026896061, step = 17701 (0.363 sec)
# INFO:tensorflow:global_step/sec: 275.428
# INFO:tensorflow:loss = 0.049177945, step = 17801 (0.363 sec)
# INFO:tensorflow:global_step/sec: 277.704
# INFO:tensorflow:loss = 0.14265364, step = 17901 (0.361 sec)
# INFO:tensorflow:global_step/sec: 276.561
# INFO:tensorflow:loss = 0.037528656, step = 18001 (0.361 sec)
# INFO:tensorflow:global_step/sec: 284.363
# INFO:tensorflow:loss = 0.15547615, step = 18101 (0.352 sec)
# INFO:tensorflow:global_step/sec: 277.704
# INFO:tensorflow:loss = 0.05056438, step = 18201 (0.361 sec)
# INFO:tensorflow:global_step/sec: 276.183
# INFO:tensorflow:loss = 0.21158004, step = 18301 (0.362 sec)
# INFO:tensorflow:global_step/sec: 276.181
# INFO:tensorflow:loss = 0.32140267, step = 18401 (0.362 sec)
# INFO:tensorflow:global_step/sec: 278.435
# INFO:tensorflow:loss = 0.008137806, step = 18501 (0.359 sec)
# INFO:tensorflow:global_step/sec: 286.829
# INFO:tensorflow:loss = 0.057414666, step = 18601 (0.349 sec)
# INFO:tensorflow:global_step/sec: 277.369
# INFO:tensorflow:loss = 0.18753093, step = 18701 (0.360 sec)
# INFO:tensorflow:global_step/sec: 277.274
# INFO:tensorflow:loss = 0.042615682, step = 18801 (0.362 sec)
# INFO:tensorflow:global_step/sec: 286.789
# INFO:tensorflow:loss = 0.12840386, step = 18901 (0.348 sec)
# INFO:tensorflow:global_step/sec: 276.183
# INFO:tensorflow:loss = 0.06505227, step = 19001 (0.363 sec)
# INFO:tensorflow:global_step/sec: 279.243
# INFO:tensorflow:loss = 0.022467408, step = 19101 (0.358 sec)
# INFO:tensorflow:global_step/sec: 287.198
# INFO:tensorflow:loss = 0.03989401, step = 19201 (0.349 sec)
# INFO:tensorflow:global_step/sec: 284.362
# INFO:tensorflow:loss = 0.07025478, step = 19301 (0.351 sec)
# INFO:tensorflow:global_step/sec: 284.765
# INFO:tensorflow:loss = 0.007896052, step = 19401 (0.352 sec)
# INFO:tensorflow:global_step/sec: 278.472
# INFO:tensorflow:loss = 0.04130406, step = 19501 (0.359 sec)
# INFO:tensorflow:global_step/sec: 281.976
# INFO:tensorflow:loss = 0.009893123, step = 19601 (0.355 sec)
# INFO:tensorflow:global_step/sec: 281.582
# INFO:tensorflow:loss = 0.09616512, step = 19701 (0.355 sec)
# INFO:tensorflow:global_step/sec: 278.472
# INFO:tensorflow:loss = 0.045767937, step = 19801 (0.359 sec)
# INFO:tensorflow:global_step/sec: 280.797
# INFO:tensorflow:loss = 0.00423067, step = 19901 (0.356 sec)
# INFO:tensorflow:global_step/sec: 286.382
# INFO:tensorflow:loss = 0.09425583, step = 20001 (0.349 sec)
# INFO:tensorflow:global_step/sec: 288.845
# INFO:tensorflow:loss = 0.053303372, step = 20101 (0.346 sec)
# INFO:tensorflow:global_step/sec: 277.321
# INFO:tensorflow:loss = 0.02993397, step = 20201 (0.360 sec)
# INFO:tensorflow:global_step/sec: 281.19
# INFO:tensorflow:loss = 0.19920582, step = 20301 (0.355 sec)
# INFO:tensorflow:global_step/sec: 282.371
# INFO:tensorflow:loss = 0.09943533, step = 20401 (0.354 sec)
# INFO:tensorflow:global_step/sec: 280.019
# INFO:tensorflow:loss = 0.16843376, step = 20501 (0.357 sec)
# INFO:tensorflow:global_step/sec: 285.166
# INFO:tensorflow:loss = 0.027603969, step = 20601 (0.351 sec)
# INFO:tensorflow:global_step/sec: 284.362
# INFO:tensorflow:loss = 0.012579855, step = 20701 (0.352 sec)
# INFO:tensorflow:global_step/sec: 279.631
# INFO:tensorflow:loss = 0.015948925, step = 20801 (0.358 sec)
# INFO:tensorflow:global_step/sec: 283.562
# INFO:tensorflow:loss = 0.05080902, step = 20901 (0.353 sec)
# INFO:tensorflow:global_step/sec: 277.703
# INFO:tensorflow:loss = 0.01970203, step = 21001 (0.360 sec)
# INFO:tensorflow:global_step/sec: 283.165
# INFO:tensorflow:loss = 0.4181678, step = 21101 (0.353 sec)
# INFO:tensorflow:global_step/sec: 278.857
# INFO:tensorflow:loss = 0.026794488, step = 21201 (0.359 sec)
# INFO:tensorflow:global_step/sec: 295.187
# INFO:tensorflow:loss = 0.18779908, step = 21301 (0.339 sec)
# INFO:tensorflow:global_step/sec: 277.704
# INFO:tensorflow:loss = 0.024538934, step = 21401 (0.360 sec)
# INFO:tensorflow:global_step/sec: 281.581
# INFO:tensorflow:loss = 0.0127615705, step = 21501 (0.355 sec)
# INFO:tensorflow:global_step/sec: 283.563
# INFO:tensorflow:loss = 0.13814223, step = 21601 (0.352 sec)
# INFO:tensorflow:global_step/sec: 283.962
# INFO:tensorflow:loss = 0.009586998, step = 21701 (0.353 sec)
# INFO:tensorflow:global_step/sec: 278.856
# INFO:tensorflow:loss = 0.0149701, step = 21801 (0.358 sec)
# INFO:tensorflow:global_step/sec: 275.427
# INFO:tensorflow:loss = 0.022572953, step = 21901 (0.364 sec)
# INFO:tensorflow:global_step/sec: 277.703
# INFO:tensorflow:loss = 0.119284905, step = 22001 (0.360 sec)
# INFO:tensorflow:global_step/sec: 279.244
# INFO:tensorflow:loss = 0.0053054616, step = 22101 (0.358 sec)
# INFO:tensorflow:global_step/sec: 278.471
# INFO:tensorflow:loss = 0.08018149, step = 22201 (0.359 sec)
# INFO:tensorflow:global_step/sec: 274.304
# INFO:tensorflow:loss = 0.029272603, step = 22301 (0.365 sec)
# INFO:tensorflow:global_step/sec: 278.856
# INFO:tensorflow:loss = 0.032424074, step = 22401 (0.359 sec)
# INFO:tensorflow:global_step/sec: 279.241
# INFO:tensorflow:loss = 0.05384083, step = 22501 (0.359 sec)
# INFO:tensorflow:global_step/sec: 275.805
# INFO:tensorflow:loss = 0.008523341, step = 22601 (0.362 sec)
# INFO:tensorflow:global_step/sec: 279.242
# INFO:tensorflow:loss = 0.074024945, step = 22701 (0.358 sec)
# INFO:tensorflow:global_step/sec: 278.472
# INFO:tensorflow:loss = 0.04836597, step = 22801 (0.359 sec)
# INFO:tensorflow:global_step/sec: 275.804
# INFO:tensorflow:loss = 0.010256095, step = 22901 (0.363 sec)
# INFO:tensorflow:global_step/sec: 277.322
# INFO:tensorflow:loss = 0.027090728, step = 23001 (0.361 sec)
# INFO:tensorflow:global_step/sec: 276.942
# INFO:tensorflow:loss = 0.023486663, step = 23101 (0.361 sec)
# INFO:tensorflow:global_step/sec: 278.855
# INFO:tensorflow:loss = 0.011767408, step = 23201 (0.359 sec)
# INFO:tensorflow:global_step/sec: 278.396
# INFO:tensorflow:loss = 0.08355631, step = 23301 (0.359 sec)
# INFO:tensorflow:global_step/sec: 278.932
# INFO:tensorflow:loss = 0.037191473, step = 23401 (0.358 sec)
# INFO:tensorflow:global_step/sec: 278.47
# INFO:tensorflow:loss = 0.032586865, step = 23501 (0.359 sec)
# INFO:tensorflow:global_step/sec: 276.184
# INFO:tensorflow:loss = 0.016259788, step = 23601 (0.362 sec)
# INFO:tensorflow:global_step/sec: 277.322
# INFO:tensorflow:loss = 0.07779123, step = 23701 (0.361 sec)
# INFO:tensorflow:global_step/sec: 276.562
# INFO:tensorflow:loss = 0.07803743, step = 23801 (0.361 sec)
# INFO:tensorflow:global_step/sec: 278.086
# INFO:tensorflow:loss = 0.004685288, step = 23901 (0.360 sec)
# INFO:tensorflow:global_step/sec: 276.942
# INFO:tensorflow:loss = 0.021420259, step = 24001 (0.361 sec)
# INFO:tensorflow:global_step/sec: 278.47
# INFO:tensorflow:loss = 0.038421765, step = 24101 (0.359 sec)
# INFO:tensorflow:global_step/sec: 278.471
# INFO:tensorflow:loss = 0.008513671, step = 24201 (0.359 sec)
# INFO:tensorflow:global_step/sec: 278.088
# INFO:tensorflow:loss = 0.033205874, step = 24301 (0.360 sec)
# INFO:tensorflow:global_step/sec: 280.018
# INFO:tensorflow:loss = 0.0152763, step = 24401 (0.357 sec)
# INFO:tensorflow:global_step/sec: 278.855
# INFO:tensorflow:loss = 0.0351248, step = 24501 (0.358 sec)
# INFO:tensorflow:global_step/sec: 279.243
# INFO:tensorflow:loss = 0.023262504, step = 24601 (0.358 sec)
# INFO:tensorflow:global_step/sec: 280.798
# INFO:tensorflow:loss = 0.0098273, step = 24701 (0.356 sec)
# INFO:tensorflow:global_step/sec: 278.856
# INFO:tensorflow:loss = 0.024213362, step = 24801 (0.359 sec)
# INFO:tensorflow:global_step/sec: 277.704
# INFO:tensorflow:loss = 0.006186601, step = 24901 (0.360 sec)
# INFO:tensorflow:global_step/sec: 277.704
# INFO:tensorflow:loss = 0.07984783, step = 25001 (0.360 sec)
# INFO:tensorflow:global_step/sec: 278.857
# INFO:tensorflow:loss = 0.049168553, step = 25101 (0.358 sec)
# INFO:tensorflow:global_step/sec: 278.087
# INFO:tensorflow:loss = 0.038584806, step = 25201 (0.360 sec)
# INFO:tensorflow:global_step/sec: 277.322
# INFO:tensorflow:loss = 0.034729786, step = 25301 (0.361 sec)
# INFO:tensorflow:global_step/sec: 277.323
# INFO:tensorflow:loss = 0.014529858, step = 25401 (0.361 sec)
# INFO:tensorflow:global_step/sec: 275.804
# INFO:tensorflow:loss = 0.007870521, step = 25501 (0.362 sec)
# INFO:tensorflow:global_step/sec: 280.408
# INFO:tensorflow:loss = 0.027114797, step = 25601 (0.357 sec)
# INFO:tensorflow:global_step/sec: 278.856
# INFO:tensorflow:loss = 0.017892862, step = 25701 (0.359 sec)
# INFO:tensorflow:global_step/sec: 278.471
# INFO:tensorflow:loss = 0.11052018, step = 25801 (0.359 sec)
# INFO:tensorflow:global_step/sec: 281.583
# INFO:tensorflow:loss = 0.02189017, step = 25901 (0.356 sec)
# INFO:tensorflow:global_step/sec: 277.702
# INFO:tensorflow:loss = 0.100752085, step = 26001 (0.360 sec)
# INFO:tensorflow:global_step/sec: 276.183
# INFO:tensorflow:loss = 0.043766394, step = 26101 (0.362 sec)
# INFO:tensorflow:global_step/sec: 283.562
# INFO:tensorflow:loss = 0.005886712, step = 26201 (0.353 sec)
# INFO:tensorflow:global_step/sec: 284.764
# INFO:tensorflow:loss = 0.035341054, step = 26301 (0.351 sec)
# INFO:tensorflow:global_step/sec: 278.472
# INFO:tensorflow:loss = 0.023356237, step = 26401 (0.359 sec)
# INFO:tensorflow:global_step/sec: 279.242
# INFO:tensorflow:loss = 0.0008458258, step = 26501 (0.359 sec)
# INFO:tensorflow:global_step/sec: 278.088
# INFO:tensorflow:loss = 0.02521369, step = 26601 (0.359 sec)
# INFO:tensorflow:global_step/sec: 279.629
# INFO:tensorflow:loss = 0.022577908, step = 26701 (0.358 sec)
# INFO:tensorflow:global_step/sec: 277.642
# INFO:tensorflow:loss = 0.055127278, step = 26801 (0.360 sec)
# INFO:tensorflow:global_step/sec: 280.862
# INFO:tensorflow:loss = 0.0077655856, step = 26901 (0.356 sec)
# INFO:tensorflow:global_step/sec: 299.129
# INFO:tensorflow:loss = 0.014536343, step = 27001 (0.334 sec)
# INFO:tensorflow:global_step/sec: 271.715
# INFO:tensorflow:loss = 0.022553837, step = 27101 (0.368 sec)
# INFO:tensorflow:global_step/sec: 288.019
# INFO:tensorflow:loss = 0.042595632, step = 27201 (0.348 sec)
# INFO:tensorflow:global_step/sec: 275.805
# INFO:tensorflow:loss = 0.016881596, step = 27301 (0.363 sec)
# INFO:tensorflow:global_step/sec: 278.087
# INFO:tensorflow:loss = 0.04736118, step = 27401 (0.360 sec)
# INFO:tensorflow:global_step/sec: 276.56
# INFO:tensorflow:loss = 0.04277336, step = 27501 (0.361 sec)
# INFO:tensorflow:global_step/sec: 275.427
# INFO:tensorflow:loss = 0.0003177969, step = 27601 (0.364 sec)
# INFO:tensorflow:global_step/sec: 277.705
# INFO:tensorflow:loss = 0.03175803, step = 27701 (0.360 sec)
# INFO:tensorflow:global_step/sec: 277.322
# INFO:tensorflow:loss = 0.012468649, step = 27801 (0.361 sec)
# INFO:tensorflow:global_step/sec: 283.563
# INFO:tensorflow:loss = 0.012178696, step = 27901 (0.352 sec)
# INFO:tensorflow:global_step/sec: 287.608
# INFO:tensorflow:loss = 0.0031705434, step = 28001 (0.347 sec)
# INFO:tensorflow:global_step/sec: 324.136
# INFO:tensorflow:loss = 0.071774244, step = 28101 (0.309 sec)
# INFO:tensorflow:global_step/sec: 277.321
# INFO:tensorflow:loss = 0.011857074, step = 28201 (0.361 sec)
# INFO:tensorflow:global_step/sec: 277.323
# INFO:tensorflow:loss = 0.017087288, step = 28301 (0.361 sec)
# INFO:tensorflow:global_step/sec: 280.406
# INFO:tensorflow:loss = 0.01880331, step = 28401 (0.357 sec)
# INFO:tensorflow:global_step/sec: 269.176
# INFO:tensorflow:loss = 0.023697875, step = 28501 (0.372 sec)
# INFO:tensorflow:global_step/sec: 276.562
# INFO:tensorflow:loss = 0.019041756, step = 28601 (0.362 sec)
# INFO:tensorflow:global_step/sec: 277.704
# INFO:tensorflow:loss = 0.028030096, step = 28701 (0.360 sec)
# INFO:tensorflow:global_step/sec: 274.304
# INFO:tensorflow:loss = 0.07471222, step = 28801 (0.365 sec)
# INFO:tensorflow:global_step/sec: 281.976
# INFO:tensorflow:loss = 0.029769657, step = 28901 (0.355 sec)
# INFO:tensorflow:global_step/sec: 287.199
# INFO:tensorflow:loss = 0.052058056, step = 29001 (0.348 sec)
# INFO:tensorflow:global_step/sec: 277.704
# INFO:tensorflow:loss = 0.009122713, step = 29101 (0.361 sec)
# INFO:tensorflow:global_step/sec: 280.407
# INFO:tensorflow:loss = 0.02820759, step = 29201 (0.356 sec)
# INFO:tensorflow:global_step/sec: 288.431
# INFO:tensorflow:loss = 0.018345954, step = 29301 (0.347 sec)
# INFO:tensorflow:global_step/sec: 282.768
# INFO:tensorflow:loss = 0.017143775, step = 29401 (0.353 sec)
# INFO:tensorflow:global_step/sec: 283.562
# INFO:tensorflow:loss = 0.0015070287, step = 29501 (0.353 sec)
# INFO:tensorflow:global_step/sec: 278.088
# INFO:tensorflow:loss = 0.022481924, step = 29601 (0.360 sec)
# INFO:tensorflow:global_step/sec: 279.63
# INFO:tensorflow:loss = 0.017410606, step = 29701 (0.357 sec)
# INFO:tensorflow:global_step/sec: 281.582
# INFO:tensorflow:loss = 0.0056290166, step = 29801 (0.355 sec)
# INFO:tensorflow:global_step/sec: 275.428
# INFO:tensorflow:loss = 0.0032763504, step = 29901 (0.363 sec)
# INFO:tensorflow:global_step/sec: 278.856
# INFO:tensorflow:loss = 0.001667137, step = 30001 (0.359 sec)
# INFO:tensorflow:global_step/sec: 277.322
# INFO:tensorflow:loss = 0.016456064, step = 30101 (0.360 sec)
# INFO:tensorflow:global_step/sec: 278.856
# INFO:tensorflow:loss = 0.038457714, step = 30201 (0.359 sec)
# INFO:tensorflow:global_step/sec: 276.183
# INFO:tensorflow:loss = 0.04173205, step = 30301 (0.362 sec)
# INFO:tensorflow:global_step/sec: 276.561
# INFO:tensorflow:loss = 0.032262243, step = 30401 (0.362 sec)
# INFO:tensorflow:global_step/sec: 277.322
# INFO:tensorflow:loss = 0.0125072375, step = 30501 (0.361 sec)
# INFO:tensorflow:global_step/sec: 274.303
# INFO:tensorflow:loss = 0.009326413, step = 30601 (0.365 sec)
# INFO:tensorflow:global_step/sec: 277.705
# INFO:tensorflow:loss = 0.06461491, step = 30701 (0.360 sec)
# INFO:tensorflow:global_step/sec: 277.322
# INFO:tensorflow:loss = 0.07050272, step = 30801 (0.361 sec)
# INFO:tensorflow:global_step/sec: 278.087
# INFO:tensorflow:loss = 0.02820296, step = 30901 (0.360 sec)
# INFO:tensorflow:global_step/sec: 275.804
# INFO:tensorflow:loss = 0.00836528, step = 31001 (0.363 sec)
# INFO:tensorflow:global_step/sec: 278.087
# INFO:tensorflow:loss = 0.010124391, step = 31101 (0.359 sec)
# INFO:tensorflow:global_step/sec: 275.427
# INFO:tensorflow:loss = 0.024193658, step = 31201 (0.363 sec)
# INFO:tensorflow:global_step/sec: 276.559
# INFO:tensorflow:loss = 0.006843343, step = 31301 (0.362 sec)
# INFO:tensorflow:global_step/sec: 278.859
# INFO:tensorflow:loss = 0.0376426, step = 31401 (0.359 sec)
# INFO:tensorflow:global_step/sec: 276.182
# INFO:tensorflow:loss = 0.017511975, step = 31501 (0.362 sec)
# INFO:tensorflow:global_step/sec: 277.322
# INFO:tensorflow:loss = 0.040600695, step = 31601 (0.361 sec)
# INFO:tensorflow:global_step/sec: 277.323
# INFO:tensorflow:loss = 0.04266322, step = 31701 (0.361 sec)
# INFO:tensorflow:global_step/sec: 276.56
# INFO:tensorflow:loss = 0.02373952, step = 31801 (0.361 sec)
# INFO:tensorflow:global_step/sec: 276.562
# INFO:tensorflow:loss = 0.0422275, step = 31901 (0.362 sec)
# INFO:tensorflow:global_step/sec: 277.32
# INFO:tensorflow:loss = 0.003730727, step = 32001 (0.361 sec)
# INFO:tensorflow:global_step/sec: 276.942
# INFO:tensorflow:loss = 0.01865583, step = 32101 (0.361 sec)
# INFO:tensorflow:global_step/sec: 279.63
# INFO:tensorflow:loss = 0.023256417, step = 32201 (0.358 sec)
# INFO:tensorflow:global_step/sec: 276.183
# INFO:tensorflow:loss = 0.016588883, step = 32301 (0.369 sec)
# INFO:tensorflow:global_step/sec: 268.424
# INFO:tensorflow:loss = 0.014823122, step = 32401 (0.366 sec)
# INFO:tensorflow:global_step/sec: 275.805
# INFO:tensorflow:loss = 0.01897286, step = 32501 (0.363 sec)
# INFO:tensorflow:global_step/sec: 274.676
# INFO:tensorflow:loss = 0.003068888, step = 32601 (0.364 sec)
# INFO:tensorflow:global_step/sec: 275.053
# INFO:tensorflow:loss = 0.0033946717, step = 32701 (0.364 sec)
# INFO:tensorflow:global_step/sec: 272.45
# INFO:tensorflow:loss = 0.017317472, step = 32801 (0.367 sec)
# INFO:tensorflow:global_step/sec: 272.818
# INFO:tensorflow:loss = 0.0106862, step = 32901 (0.366 sec)
# INFO:tensorflow:global_step/sec: 276.561
# INFO:tensorflow:loss = 0.044534422, step = 33001 (0.362 sec)
# INFO:tensorflow:global_step/sec: 276.183
# INFO:tensorflow:loss = 0.03534149, step = 33101 (0.362 sec)
# INFO:tensorflow:global_step/sec: 277.703
# INFO:tensorflow:loss = 0.023458224, step = 33201 (0.381 sec)
# INFO:tensorflow:global_step/sec: 250.665
# INFO:tensorflow:loss = 0.04128658, step = 33301 (0.378 sec)
# INFO:tensorflow:global_step/sec: 264.578
# INFO:tensorflow:loss = 0.020117732, step = 33401 (0.378 sec)
# INFO:tensorflow:global_step/sec: 270.292
# INFO:tensorflow:loss = 0.028590634, step = 33501 (0.370 sec)
# INFO:tensorflow:global_step/sec: 276.185
# INFO:tensorflow:loss = 0.012856969, step = 33601 (0.362 sec)
# INFO:tensorflow:global_step/sec: 269.866
# INFO:tensorflow:loss = 0.06938368, step = 33701 (0.371 sec)
# INFO:tensorflow:global_step/sec: 269.206
# INFO:tensorflow:loss = 0.009129054, step = 33801 (0.372 sec)
# INFO:tensorflow:global_step/sec: 272.084
# INFO:tensorflow:loss = 0.0013068642, step = 33901 (0.368 sec)
# INFO:tensorflow:global_step/sec: 279.626
# INFO:tensorflow:loss = 0.010660597, step = 34001 (0.357 sec)
# INFO:tensorflow:global_step/sec: 276.944
# INFO:tensorflow:loss = 0.010582399, step = 34101 (0.361 sec)
# INFO:tensorflow:global_step/sec: 272.819
# INFO:tensorflow:loss = 0.018475695, step = 34201 (0.367 sec)
# INFO:tensorflow:global_step/sec: 277.092
# INFO:tensorflow:loss = 0.06488151, step = 34301 (0.360 sec)
# INFO:tensorflow:global_step/sec: 282.215
# INFO:tensorflow:loss = 0.027864065, step = 34401 (0.355 sec)
# INFO:tensorflow:global_step/sec: 284.362
# INFO:tensorflow:loss = 0.0005569991, step = 34501 (0.352 sec)
# INFO:tensorflow:global_step/sec: 288.846
# INFO:tensorflow:loss = 0.019970115, step = 34601 (0.346 sec)
# INFO:tensorflow:global_step/sec: 439.243
# INFO:tensorflow:loss = 0.0743283, step = 34701 (0.227 sec)
# INFO:tensorflow:global_step/sec: 427.146
# INFO:tensorflow:loss = 0.021255761, step = 34801 (0.234 sec)
# INFO:tensorflow:global_step/sec: 310.651
# INFO:tensorflow:loss = 0.013148524, step = 34901 (0.323 sec)
# INFO:tensorflow:global_step/sec: 285.168
# INFO:tensorflow:loss = 0.0020463371, step = 35001 (0.351 sec)
# INFO:tensorflow:global_step/sec: 276.181
# INFO:tensorflow:loss = 0.018659376, step = 35101 (0.362 sec)
# INFO:tensorflow:global_step/sec: 279.63
# INFO:tensorflow:loss = 0.025659695, step = 35201 (0.358 sec)
# INFO:tensorflow:global_step/sec: 277.703
# INFO:tensorflow:loss = 0.0075600934, step = 35301 (0.360 sec)
# INFO:tensorflow:global_step/sec: 280.798
# INFO:tensorflow:loss = 0.010623997, step = 35401 (0.356 sec)
# INFO:tensorflow:global_step/sec: 276.942
# INFO:tensorflow:loss = 0.004094276, step = 35501 (0.361 sec)
# INFO:tensorflow:global_step/sec: 277.321
# INFO:tensorflow:loss = 0.027924761, step = 35601 (0.361 sec)
# INFO:tensorflow:global_step/sec: 277.703
# INFO:tensorflow:loss = 0.01468807, step = 35701 (0.361 sec)
# INFO:tensorflow:global_step/sec: 279.243
# INFO:tensorflow:loss = 0.0093727475, step = 35801 (0.358 sec)
# INFO:tensorflow:global_step/sec: 278.087
# INFO:tensorflow:loss = 0.0036358917, step = 35901 (0.360 sec)
# INFO:tensorflow:global_step/sec: 281.977
# INFO:tensorflow:loss = 0.05732041, step = 36001 (0.354 sec)
# INFO:tensorflow:global_step/sec: 278.472
# INFO:tensorflow:loss = 0.043912467, step = 36101 (0.360 sec)
# INFO:tensorflow:global_step/sec: 277.32
# INFO:tensorflow:loss = 0.022222653, step = 36201 (0.360 sec)
# INFO:tensorflow:global_step/sec: 276.942
# INFO:tensorflow:loss = 0.0016120024, step = 36301 (0.362 sec)
# INFO:tensorflow:global_step/sec: 282.769
# INFO:tensorflow:loss = 0.0028571608, step = 36401 (0.354 sec)
# INFO:tensorflow:global_step/sec: 284.363
# INFO:tensorflow:loss = 0.015895823, step = 36501 (0.351 sec)
# INFO:tensorflow:global_step/sec: 286.789
# INFO:tensorflow:loss = 0.0026730094, step = 36601 (0.349 sec)
# INFO:tensorflow:global_step/sec: 280.407
# INFO:tensorflow:loss = 0.026629439, step = 36701 (0.357 sec)
# INFO:tensorflow:global_step/sec: 279.242
# INFO:tensorflow:loss = 0.004633099, step = 36801 (0.358 sec)
# INFO:tensorflow:global_step/sec: 287.608
# INFO:tensorflow:loss = 0.027259646, step = 36901 (0.347 sec)
# INFO:tensorflow:global_step/sec: 278.857
# INFO:tensorflow:loss = 0.0038641628, step = 37001 (0.359 sec)
# INFO:tensorflow:global_step/sec: 286.789
# INFO:tensorflow:loss = 0.029732473, step = 37101 (0.349 sec)
# INFO:tensorflow:global_step/sec: 281.975
# INFO:tensorflow:loss = 0.0117097385, step = 37201 (0.355 sec)
# INFO:tensorflow:global_step/sec: 282.768
# INFO:tensorflow:loss = 0.039483465, step = 37301 (0.354 sec)
# INFO:tensorflow:global_step/sec: 294.326
# INFO:tensorflow:loss = 0.018409513, step = 37401 (0.339 sec)
# INFO:tensorflow:global_step/sec: 282.768
# INFO:tensorflow:loss = 0.0041273637, step = 37501 (0.354 sec)
# INFO:tensorflow:global_step/sec: 285.975
# INFO:tensorflow:loss = 0.014782869, step = 37601 (0.349 sec)
# INFO:tensorflow:global_step/sec: 283.961
# INFO:tensorflow:loss = 0.02106044, step = 37701 (0.353 sec)
# INFO:tensorflow:global_step/sec: 285.572
# INFO:tensorflow:loss = 0.029760003, step = 37801 (0.350 sec)
# INFO:tensorflow:global_step/sec: 280.798
# INFO:tensorflow:loss = 0.0018186925, step = 37901 (0.356 sec)
# INFO:tensorflow:global_step/sec: 274.303
# INFO:tensorflow:loss = 0.0075440085, step = 38001 (0.365 sec)
# INFO:tensorflow:global_step/sec: 276.942
# INFO:tensorflow:loss = 0.000476402, step = 38101 (0.361 sec)
# INFO:tensorflow:global_step/sec: 266.674
# INFO:tensorflow:loss = 0.041034214, step = 38201 (0.375 sec)
# INFO:tensorflow:global_step/sec: 273.199
# INFO:tensorflow:loss = 0.0048142658, step = 38301 (0.366 sec)
# INFO:tensorflow:global_step/sec: 273.188
# INFO:tensorflow:loss = 0.03812752, step = 38401 (0.366 sec)
# INFO:tensorflow:global_step/sec: 269.176
# INFO:tensorflow:loss = 0.0014221391, step = 38501 (0.372 sec)
# INFO:tensorflow:global_step/sec: 273.559
# INFO:tensorflow:loss = 0.006695306, step = 38601 (0.365 sec)
# INFO:tensorflow:global_step/sec: 274.304
# INFO:tensorflow:loss = 0.006142506, step = 38701 (0.365 sec)
# INFO:tensorflow:global_step/sec: 272.82
# INFO:tensorflow:loss = 0.021008682, step = 38801 (0.367 sec)
# INFO:tensorflow:global_step/sec: 275.427
# INFO:tensorflow:loss = 0.029855924, step = 38901 (0.363 sec)
# INFO:tensorflow:global_step/sec: 274.304
# INFO:tensorflow:loss = 0.0590635, step = 39001 (0.365 sec)
# INFO:tensorflow:global_step/sec: 276.181
# INFO:tensorflow:loss = 0.009500089, step = 39101 (0.362 sec)
# INFO:tensorflow:global_step/sec: 276.811
# INFO:tensorflow:loss = 0.0040931385, step = 39201 (0.362 sec)
# INFO:tensorflow:global_step/sec: 274.43
# INFO:tensorflow:loss = 0.0014048847, step = 39301 (0.364 sec)
# INFO:tensorflow:global_step/sec: 276.943
# INFO:tensorflow:loss = 0.0045304596, step = 39401 (0.361 sec)
# INFO:tensorflow:global_step/sec: 278.087
# INFO:tensorflow:loss = 0.019826133, step = 39501 (0.360 sec)
# INFO:tensorflow:global_step/sec: 273.56
# INFO:tensorflow:loss = 0.010441447, step = 39601 (0.366 sec)
# INFO:tensorflow:global_step/sec: 277.704
# INFO:tensorflow:loss = 0.0011155687, step = 39701 (0.360 sec)
# INFO:tensorflow:global_step/sec: 276.181
# INFO:tensorflow:loss = 0.014149386, step = 39801 (0.362 sec)
# INFO:tensorflow:global_step/sec: 276.182
# INFO:tensorflow:loss = 0.026339658, step = 39901 (0.362 sec)
# INFO:tensorflow:global_step/sec: 276.942
# INFO:tensorflow:loss = 0.008569269, step = 40001 (0.361 sec)
# INFO:tensorflow:global_step/sec: 277.321
# INFO:tensorflow:loss = 0.011670921, step = 40101 (0.361 sec)
# INFO:tensorflow:global_step/sec: 275.804
# INFO:tensorflow:loss = 0.014685072, step = 40201 (0.363 sec)
# INFO:tensorflow:global_step/sec: 275.805
# INFO:tensorflow:loss = 0.017549802, step = 40301 (0.363 sec)
# INFO:tensorflow:global_step/sec: 274.304
# INFO:tensorflow:loss = 0.0064867726, step = 40401 (0.364 sec)
# INFO:tensorflow:global_step/sec: 277.322
# INFO:tensorflow:loss = 0.0017966317, step = 40501 (0.361 sec)
# INFO:tensorflow:global_step/sec: 276.182
# INFO:tensorflow:loss = 0.024642268, step = 40601 (0.363 sec)
# INFO:tensorflow:global_step/sec: 276.139
# INFO:tensorflow:loss = 0.014403531, step = 40701 (0.362 sec)
# INFO:tensorflow:global_step/sec: 277.366
# INFO:tensorflow:loss = 0.029289797, step = 40801 (0.361 sec)
# INFO:tensorflow:global_step/sec: 278.086
# INFO:tensorflow:loss = 0.0016229715, step = 40901 (0.360 sec)
# INFO:tensorflow:global_step/sec: 273.19
# INFO:tensorflow:loss = 0.0073337974, step = 41001 (0.366 sec)
# INFO:tensorflow:global_step/sec: 278.47
# INFO:tensorflow:loss = 0.013554333, step = 41101 (0.359 sec)
# INFO:tensorflow:global_step/sec: 278.473
# INFO:tensorflow:loss = 0.005380202, step = 41201 (0.359 sec)
# INFO:tensorflow:global_step/sec: 277.321
# INFO:tensorflow:loss = 0.009189561, step = 41301 (0.361 sec)
# INFO:tensorflow:global_step/sec: 279.629
# INFO:tensorflow:loss = 0.009137462, step = 41401 (0.358 sec)
# INFO:tensorflow:global_step/sec: 278.472
# INFO:tensorflow:loss = 0.0129450625, step = 41501 (0.359 sec)
# INFO:tensorflow:global_step/sec: 278.855
# INFO:tensorflow:loss = 0.010495837, step = 41601 (0.359 sec)
# INFO:tensorflow:global_step/sec: 278.089
# INFO:tensorflow:loss = 0.009322272, step = 41701 (0.360 sec)
# INFO:tensorflow:global_step/sec: 279.241
# INFO:tensorflow:loss = 0.0068902886, step = 41801 (0.358 sec)
# INFO:tensorflow:global_step/sec: 278.471
# INFO:tensorflow:loss = 0.007426015, step = 41901 (0.359 sec)
# INFO:tensorflow:global_step/sec: 279.629
# INFO:tensorflow:loss = 0.00851425, step = 42001 (0.358 sec)
# INFO:tensorflow:global_step/sec: 281.584
# INFO:tensorflow:loss = 0.00753411, step = 42101 (0.355 sec)
# INFO:tensorflow:global_step/sec: 279.629
# INFO:tensorflow:loss = 0.010088254, step = 42201 (0.358 sec)
# INFO:tensorflow:global_step/sec: 278.088
# INFO:tensorflow:loss = 0.003890129, step = 42301 (0.359 sec)
# INFO:tensorflow:global_step/sec: 280.798
# INFO:tensorflow:loss = 0.00810605, step = 42401 (0.356 sec)
# INFO:tensorflow:global_step/sec: 277.204
# INFO:tensorflow:loss = 0.03429666, step = 42501 (0.361 sec)
# INFO:tensorflow:global_step/sec: 277.439
# INFO:tensorflow:loss = 0.010447169, step = 42601 (0.361 sec)
# INFO:tensorflow:global_step/sec: 283.166
# INFO:tensorflow:loss = 0.0076125665, step = 42701 (0.353 sec)
# INFO:tensorflow:global_step/sec: 278.086
# INFO:tensorflow:loss = 0.009727977, step = 42801 (0.359 sec)
# INFO:tensorflow:global_step/sec: 281.189
# INFO:tensorflow:loss = 0.00036820432, step = 42901 (0.356 sec)
# INFO:tensorflow:global_step/sec: 276.183
# INFO:tensorflow:loss = 0.008924848, step = 43001 (0.362 sec)
# INFO:tensorflow:global_step/sec: 280.017
# INFO:tensorflow:loss = 0.005926582, step = 43101 (0.358 sec)
# INFO:tensorflow:global_step/sec: 277.704
# INFO:tensorflow:loss = 0.045594845, step = 43201 (0.360 sec)
# INFO:tensorflow:global_step/sec: 278.471
# INFO:tensorflow:loss = 0.009966625, step = 43301 (0.359 sec)
# INFO:tensorflow:global_step/sec: 275.428
# INFO:tensorflow:loss = 0.015677232, step = 43401 (0.364 sec)
# INFO:tensorflow:global_step/sec: 265.63
# INFO:tensorflow:loss = 0.011222709, step = 43501 (0.376 sec)
# INFO:tensorflow:global_step/sec: 303.179
# INFO:tensorflow:loss = 0.014647047, step = 43601 (0.330 sec)
# INFO:tensorflow:global_step/sec: 284.763
# INFO:tensorflow:loss = 0.026559925, step = 43701 (0.352 sec)
# INFO:tensorflow:global_step/sec: 297.365
# INFO:tensorflow:loss = 0.013407135, step = 43801 (0.336 sec)
# INFO:tensorflow:global_step/sec: 299.574
# INFO:tensorflow:loss = 0.03723149, step = 43901 (0.334 sec)
# INFO:tensorflow:Saving checkpoints for 44000 into C:\Users\manog\AppData\Local\Temp\tmps050b1z7\model.ckpt.
# INFO:tensorflow:Loss for final step: 0.019600555.

# %%
test_input_fn = tf.estimator.inputs.numpy_input_fn(x = {"X": X_test}, y = y_test, shuffle = False)
eval_results = dnn_clf.evaluate(input_fn = test_input_fn)
# Out:
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-06-12T19:13:21Z
# INFO:tensorflow:Graph was finalized.
# WARNING:tensorflow:From C:\Users\manog\Anaconda3\lib\site-packages\tensorflow\python\training\saver.py:1266: checkpoint_exists (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to check for files with this prefix.
# INFO:tensorflow:Restoring parameters from C:\Users\manog\AppData\Local\Temp\tmps050b1z7\model.ckpt-44000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-06-12-19:13:21
# INFO:tensorflow:Saving dict for global step 44000: accuracy = 0.9794, average_loss = 0.1085036, global_step = 44000, loss = 13.734633
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 44000: C:\Users\manog\AppData\Local\Temp\tmps050b1z7\model.ckpt-44000

# %%
eval_results
# Out:
# {'accuracy': 0.9794,
#  'average_loss': 0.1085036,
#  'loss': 13.734633,
#  'global_step': 44000}

# %% [markdown]
# By running the above mentioned DNN for classification on the earlier taken MNIST dataset, we got a model that has accuracy over 98% on the testing set.

# %%
y_pred_iter = dnn_clf.predict(input_fn = test_input_fn)
y_pred = list(y_pred_iter)
# Out:
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from C:\Users\manog\AppData\Local\Temp\tmps050b1z7\model.ckpt-44000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.

# %%
y_pred[0]
# Out:
# {'logits': array([ -7.886765 ,   0.1859046,  -1.1919025,   5.61782  ,  -5.2724557,
#          -6.1540008, -18.582842 ,  22.397022 ,  -5.5561256,   1.4554625],
#        dtype=float32),
#  'probabilities': array([7.0456085e-14, 2.2585751e-10, 5.6945615e-11, 5.1628007e-08,
#         9.6227366e-13, 3.9851811e-13, 1.5946681e-18, 1.0000000e+00,
#         7.2460636e-13, 8.0388984e-10], dtype=float32),
#  'class_ids': array([7], dtype=int64),
#  'classes': array([b'7'], dtype=object)}

# %% [markdown]
# Now, we will train a DNN for classification with the same above mentioned MLP architecture using Plain TensorFlow (lower- level Python API).

# %% [markdown]
# We will take the MNIST dataset and the first step is the Construction phase, where TensorFlow graph is built.

# %%
import tensorflow as tf

# %%
n_inputs = 28*28     # number of inputs in MNIST dataset
n_hidden1 = 300
n_hidden2 = 100
n_outputs = 10      # number of outputs in the softmax output layer

# %% [markdown]
# We create placeholders for the inputs and the targets.

# %%
X = tf.placeholder(tf.float32, shape = (None, n_inputs), name = "X")
y = tf.placeholder(tf.int64, shape = (None), name = "y")

# %% [markdown]
# Now, we will create a neuron_layer() function that will be used to create one layer at a time. It will need parameters to specify the inputs, the number of neurons, the activation function, and the name of the layer.

# %%
def neuron_layer(X, n_neurons, name, activation = None):
    with tf.name_scope(name):
        n_inputs = int(X.get_shape()[1])    # number of inputs in 2nd dimension and number of instances in the 1st dimension
        stddev = 2 / np.sqrt(n_inputs)     # standard deviation helps the algorithm to converge faster  
        init = tf.truncated_normal((n_inputs, n_neurons), stddev = stddev)    # shape of W variable
        W = tf.Variable(init, name="weights")  # weights matrix, 2D tensor of connection weights b/w each input & each neuron
        b = tf.Variable(tf.zeros([n_neurons]), name = "bias")    # one bias parameter per neuron
        z = tf.matmul(X, W) + b
        if activation == "relu":
            return tf.nn.relu(z)
        else:
            return z

# %% [markdown]
# Now, we will use this neuron_layer() function to create the DNN with the above mentioned MLP architecture.

# %%
with tf.name_scope("dnn"):
    hidden1 = neuron_layer(X, n_hidden1, "hidden1", activation = "relu")
    hidden2 = neuron_layer(hidden1, n_hidden2, "hidden2", activation = "relu")
    logits = neuron_layer(hidden2, n_outputs, "outputs")

# %% [markdown]
# Now, we will define the cost function "cross entropy" that will be used to train the neural network model and then compute the mean cross entropy over all instances.

# %%
with tf.name_scope("loss"):
    cross_entropy = tf.nn.sparse_softmax_cross_entropy_with_logits(labels = y, logits = logits)   # 1D tensor containing 
                                                                                       # the cross entropy for each instance
    loss = tf.reduce_mean(cross_entropy, name = "loss")

# %% [markdown]
# Now, we need to define a "GradientDescentOptimizer" that will tweak the model parameters to minimize the cost function.

# %%
learning_rate = 0.01

with tf.name_scope("train"):
    optimizer = tf.train.GradientDescentOptimizer(learning_rate)
    train_out = optimizer.minimize(loss)

# %% [markdown]
# The last important step in the Construction phase is to specify how to evaluate the model.

# %%
with tf.name_scope("eval"):
    correct_pred = tf.cast(tf.nn.in_top_k(logits, y, 1), tf.float32)   # determine if the neural network’s prediction is 
                                                  # correct by checking whether or not the highest logit corresponds to the
                                                  # target class. cast these 1D tensor of booleans to float.
    accuracy = tf.reduce_mean(correct_pred)     # network's overall accuracy as our performance measure

# %% [markdown]
# We need to create a node to initialize all variables, and we will also create a Saver to save our trained model parameters to disk.

# %%
init = tf.global_variables_initializer()
saver = tf.train.Saver()

# %% [markdown]
# The next step is the Execution phase, where we run the above built graph to train the model.

# %%
n_epochs = 400    # number of epochs to be run
batch_size = 50    # size of the mini-batches

# %% [markdown]
# Now, we train the model using Mini-batch Gradient Descent.

# %%
def shuffle_batch(X, y, batch_size):
    rnd_idx = np.random.permutation(len(X))
    n_batches = len(X) // batch_size
    for batch_idx in np.array_split(rnd_idx, n_batches):
        X_batch, y_batch = X[batch_idx], y[batch_idx]
        yield X_batch, y_batch

# %%
with tf.Session() as sess:
    init.run()
    for epoch in range(n_epochs):
        for X_batch, y_batch in shuffle_batch(X_train, y_train, batch_size):   # iterates through a number of mini-batches 
                                                                               # that corresponds to the training set size.
            sess.run(train_out, feed_dict = {X: X_batch, y: y_batch})
        acc_batch = accuracy.eval(feed_dict = {X: X_batch, y: y_batch})
        acc_test = accuracy.eval(feed_dict = {X: X_valid, y: y_valid})
        print(epoch, "Batch accuracy:", acc_batch, "Test accuracy:", acc_test)

    save_path = saver.save(sess, "./my_model_final.ckpt")     # model parameters are saved to disk.
# Out:
# 0 Batch accuracy: 0.88 Test accuracy: 0.9126
# 1 Batch accuracy: 0.98 Test accuracy: 0.9322
# 2 Batch accuracy: 0.92 Test accuracy: 0.9418
# 3 Batch accuracy: 0.92 Test accuracy: 0.9482
# 4 Batch accuracy: 0.94 Test accuracy: 0.9518
# 5 Batch accuracy: 0.98 Test accuracy: 0.9572
# 6 Batch accuracy: 0.98 Test accuracy: 0.9584
# 7 Batch accuracy: 1.0 Test accuracy: 0.9626
# 8 Batch accuracy: 0.98 Test accuracy: 0.9642
# 9 Batch accuracy: 0.98 Test accuracy: 0.9658
# 10 Batch accuracy: 1.0 Test accuracy: 0.9686
# 11 Batch accuracy: 0.98 Test accuracy: 0.9682
# 12 Batch accuracy: 0.98 Test accuracy: 0.9686
# 13 Batch accuracy: 0.98 Test accuracy: 0.971
# 14 Batch accuracy: 0.98 Test accuracy: 0.9722
# 15 Batch accuracy: 1.0 Test accuracy: 0.9722
# 16 Batch accuracy: 1.0 Test accuracy: 0.9742
# 17 Batch accuracy: 0.98 Test accuracy: 0.974
# 18 Batch accuracy: 0.94 Test accuracy: 0.9762
# 19 Batch accuracy: 0.98 Test accuracy: 0.975
# 20 Batch accuracy: 0.98 Test accuracy: 0.9764
# 21 Batch accuracy: 1.0 Test accuracy: 0.9758
# 22 Batch accuracy: 0.98 Test accuracy: 0.977
# 23 Batch accuracy: 1.0 Test accuracy: 0.9766
# 24 Batch accuracy: 1.0 Test accuracy: 0.9772
# 25 Batch accuracy: 1.0 Test accuracy: 0.9774
# 26 Batch accuracy: 0.98 Test accuracy: 0.9776
# 27 Batch accuracy: 0.98 Test accuracy: 0.9786
# 28 Batch accuracy: 1.0 Test accuracy: 0.9784
# 29 Batch accuracy: 1.0 Test accuracy: 0.9788
# 30 Batch accuracy: 1.0 Test accuracy: 0.9788
# 31 Batch accuracy: 1.0 Test accuracy: 0.9794
# 32 Batch accuracy: 1.0 Test accuracy: 0.9792
# 33 Batch accuracy: 1.0 Test accuracy: 0.9788
# 34 Batch accuracy: 1.0 Test accuracy: 0.9796
# 35 Batch accuracy: 1.0 Test accuracy: 0.9784
# 36 Batch accuracy: 1.0 Test accuracy: 0.9786
# 37 Batch accuracy: 0.98 Test accuracy: 0.9796
# 38 Batch accuracy: 1.0 Test accuracy: 0.9804
# 39 Batch accuracy: 1.0 Test accuracy: 0.9798
# 40 Batch accuracy: 1.0 Test accuracy: 0.9798
# 41 Batch accuracy: 1.0 Test accuracy: 0.9798
# 42 Batch accuracy: 1.0 Test accuracy: 0.9796
# 43 Batch accuracy: 1.0 Test accuracy: 0.9802
# 44 Batch accuracy: 1.0 Test accuracy: 0.9804
# 45 Batch accuracy: 1.0 Test accuracy: 0.9802
# 46 Batch accuracy: 1.0 Test accuracy: 0.9806
# 47 Batch accuracy: 1.0 Test accuracy: 0.9796
# 48 Batch accuracy: 1.0 Test accuracy: 0.9798
# 49 Batch accuracy: 1.0 Test accuracy: 0.9806
# 50 Batch accuracy: 1.0 Test accuracy: 0.98
# 51 Batch accuracy: 1.0 Test accuracy: 0.9796
# 52 Batch accuracy: 1.0 Test accuracy: 0.9802
# 53 Batch accuracy: 1.0 Test accuracy: 0.9802
# 54 Batch accuracy: 1.0 Test accuracy: 0.9796
# 55 Batch accuracy: 1.0 Test accuracy: 0.9786
# 56 Batch accuracy: 1.0 Test accuracy: 0.9782
# 57 Batch accuracy: 1.0 Test accuracy: 0.9804
# 58 Batch accuracy: 1.0 Test accuracy: 0.9796
# 59 Batch accuracy: 1.0 Test accuracy: 0.9796
# 60 Batch accuracy: 1.0 Test accuracy: 0.979
# 61 Batch accuracy: 1.0 Test accuracy: 0.9792
# 62 Batch accuracy: 1.0 Test accuracy: 0.9794
# 63 Batch accuracy: 1.0 Test accuracy: 0.98
# 64 Batch accuracy: 1.0 Test accuracy: 0.9792
# 65 Batch accuracy: 1.0 Test accuracy: 0.9796
# 66 Batch accuracy: 1.0 Test accuracy: 0.9794
# 67 Batch accuracy: 1.0 Test accuracy: 0.9798
# 68 Batch accuracy: 1.0 Test accuracy: 0.98
# 69 Batch accuracy: 1.0 Test accuracy: 0.9796
# 70 Batch accuracy: 1.0 Test accuracy: 0.9796
# 71 Batch accuracy: 1.0 Test accuracy: 0.9804
# 72 Batch accuracy: 1.0 Test accuracy: 0.9792
# 73 Batch accuracy: 1.0 Test accuracy: 0.9802
# 74 Batch accuracy: 1.0 Test accuracy: 0.9796
# 75 Batch accuracy: 1.0 Test accuracy: 0.9796
# 76 Batch accuracy: 1.0 Test accuracy: 0.98
# 77 Batch accuracy: 1.0 Test accuracy: 0.9798
# 78 Batch accuracy: 1.0 Test accuracy: 0.98
# 79 Batch accuracy: 1.0 Test accuracy: 0.979
# 80 Batch accuracy: 1.0 Test accuracy: 0.9794
# 81 Batch accuracy: 1.0 Test accuracy: 0.9796
# 82 Batch accuracy: 1.0 Test accuracy: 0.9788
# 83 Batch accuracy: 1.0 Test accuracy: 0.9802
# 84 Batch accuracy: 1.0 Test accuracy: 0.9794
# 85 Batch accuracy: 1.0 Test accuracy: 0.9798
# 86 Batch accuracy: 1.0 Test accuracy: 0.9792
# 87 Batch accuracy: 1.0 Test accuracy: 0.9796
# 88 Batch accuracy: 0.98 Test accuracy: 0.9794
# 89 Batch accuracy: 1.0 Test accuracy: 0.979
# 90 Batch accuracy: 1.0 Test accuracy: 0.9788
# 91 Batch accuracy: 1.0 Test accuracy: 0.9794
# 92 Batch accuracy: 1.0 Test accuracy: 0.9794
# 93 Batch accuracy: 1.0 Test accuracy: 0.9796
# 94 Batch accuracy: 1.0 Test accuracy: 0.9796
# 95 Batch accuracy: 1.0 Test accuracy: 0.9798
# 96 Batch accuracy: 1.0 Test accuracy: 0.9792
# 97 Batch accuracy: 1.0 Test accuracy: 0.979
# 98 Batch accuracy: 1.0 Test accuracy: 0.9794
# 99 Batch accuracy: 1.0 Test accuracy: 0.98
# 100 Batch accuracy: 1.0 Test accuracy: 0.9798
# 101 Batch accuracy: 1.0 Test accuracy: 0.9794
# 102 Batch accuracy: 1.0 Test accuracy: 0.9794
# 103 Batch accuracy: 1.0 Test accuracy: 0.9792
# 104 Batch accuracy: 1.0 Test accuracy: 0.9792
# 105 Batch accuracy: 1.0 Test accuracy: 0.9798
# 106 Batch accuracy: 1.0 Test accuracy: 0.9798
# 107 Batch accuracy: 1.0 Test accuracy: 0.9798
# 108 Batch accuracy: 1.0 Test accuracy: 0.9794
# 109 Batch accuracy: 1.0 Test accuracy: 0.9798
# 110 Batch accuracy: 1.0 Test accuracy: 0.9796
# 111 Batch accuracy: 1.0 Test accuracy: 0.9794
# 112 Batch accuracy: 1.0 Test accuracy: 0.9796
# 113 Batch accuracy: 1.0 Test accuracy: 0.9796
# 114 Batch accuracy: 1.0 Test accuracy: 0.9792
# 115 Batch accuracy: 1.0 Test accuracy: 0.9796
# 116 Batch accuracy: 1.0 Test accuracy: 0.9796
# 117 Batch accuracy: 1.0 Test accuracy: 0.9796
# 118 Batch accuracy: 1.0 Test accuracy: 0.9794
# 119 Batch accuracy: 1.0 Test accuracy: 0.98
# 120 Batch accuracy: 1.0 Test accuracy: 0.9796
# 121 Batch accuracy: 1.0 Test accuracy: 0.9794
# 122 Batch accuracy: 1.0 Test accuracy: 0.9798
# 123 Batch accuracy: 1.0 Test accuracy: 0.9798
# 124 Batch accuracy: 1.0 Test accuracy: 0.9794
# 125 Batch accuracy: 1.0 Test accuracy: 0.979
# 126 Batch accuracy: 1.0 Test accuracy: 0.9796
# 127 Batch accuracy: 1.0 Test accuracy: 0.9794
# 128 Batch accuracy: 1.0 Test accuracy: 0.9796
# 129 Batch accuracy: 1.0 Test accuracy: 0.9794
# 130 Batch accuracy: 1.0 Test accuracy: 0.9792
# 131 Batch accuracy: 1.0 Test accuracy: 0.9794
# 132 Batch accuracy: 1.0 Test accuracy: 0.98
# 133 Batch accuracy: 1.0 Test accuracy: 0.9798
# 134 Batch accuracy: 1.0 Test accuracy: 0.9794
# 135 Batch accuracy: 1.0 Test accuracy: 0.9798
# 136 Batch accuracy: 1.0 Test accuracy: 0.9798
# 137 Batch accuracy: 1.0 Test accuracy: 0.9794
# 138 Batch accuracy: 1.0 Test accuracy: 0.9798
# 139 Batch accuracy: 1.0 Test accuracy: 0.9796
# 140 Batch accuracy: 1.0 Test accuracy: 0.98
# 141 Batch accuracy: 1.0 Test accuracy: 0.9796
# 142 Batch accuracy: 1.0 Test accuracy: 0.9798
# 143 Batch accuracy: 1.0 Test accuracy: 0.98
# 144 Batch accuracy: 1.0 Test accuracy: 0.9796
# 145 Batch accuracy: 1.0 Test accuracy: 0.9796
# 146 Batch accuracy: 1.0 Test accuracy: 0.9794
# 147 Batch accuracy: 1.0 Test accuracy: 0.9798
# 148 Batch accuracy: 1.0 Test accuracy: 0.98
# 149 Batch accuracy: 1.0 Test accuracy: 0.9798
# 150 Batch accuracy: 1.0 Test accuracy: 0.9794
# 151 Batch accuracy: 1.0 Test accuracy: 0.9798
# 152 Batch accuracy: 1.0 Test accuracy: 0.9796
# 153 Batch accuracy: 1.0 Test accuracy: 0.98
# 154 Batch accuracy: 1.0 Test accuracy: 0.9802
# 155 Batch accuracy: 1.0 Test accuracy: 0.9794
# 156 Batch accuracy: 1.0 Test accuracy: 0.9798
# 157 Batch accuracy: 1.0 Test accuracy: 0.9798
# 158 Batch accuracy: 1.0 Test accuracy: 0.9796
# 159 Batch accuracy: 1.0 Test accuracy: 0.9796
# 160 Batch accuracy: 1.0 Test accuracy: 0.9794
# 161 Batch accuracy: 1.0 Test accuracy: 0.9794
# 162 Batch accuracy: 1.0 Test accuracy: 0.9798
# 163 Batch accuracy: 1.0 Test accuracy: 0.9796
# 164 Batch accuracy: 1.0 Test accuracy: 0.9798
# 165 Batch accuracy: 1.0 Test accuracy: 0.9798
# 166 Batch accuracy: 1.0 Test accuracy: 0.9798
# 167 Batch accuracy: 1.0 Test accuracy: 0.9796
# 168 Batch accuracy: 1.0 Test accuracy: 0.98
# 169 Batch accuracy: 1.0 Test accuracy: 0.9798
# 170 Batch accuracy: 1.0 Test accuracy: 0.98
# 171 Batch accuracy: 1.0 Test accuracy: 0.9796
# 172 Batch accuracy: 1.0 Test accuracy: 0.9798
# 173 Batch accuracy: 1.0 Test accuracy: 0.9796
# 174 Batch accuracy: 1.0 Test accuracy: 0.9796
# 175 Batch accuracy: 1.0 Test accuracy: 0.9796
# 176 Batch accuracy: 1.0 Test accuracy: 0.9796
# 177 Batch accuracy: 1.0 Test accuracy: 0.9798
# 178 Batch accuracy: 1.0 Test accuracy: 0.9798
# 179 Batch accuracy: 1.0 Test accuracy: 0.9798
# 180 Batch accuracy: 1.0 Test accuracy: 0.9798
# 181 Batch accuracy: 1.0 Test accuracy: 0.9798
# 182 Batch accuracy: 1.0 Test accuracy: 0.98
# 183 Batch accuracy: 1.0 Test accuracy: 0.9798
# 184 Batch accuracy: 1.0 Test accuracy: 0.9796
# 185 Batch accuracy: 1.0 Test accuracy: 0.9798
# 186 Batch accuracy: 1.0 Test accuracy: 0.9794
# 187 Batch accuracy: 1.0 Test accuracy: 0.98
# 188 Batch accuracy: 1.0 Test accuracy: 0.9798
# 189 Batch accuracy: 1.0 Test accuracy: 0.9794
# 190 Batch accuracy: 1.0 Test accuracy: 0.9798
# 191 Batch accuracy: 1.0 Test accuracy: 0.9796
# 192 Batch accuracy: 1.0 Test accuracy: 0.98
# 193 Batch accuracy: 1.0 Test accuracy: 0.9796
# 194 Batch accuracy: 1.0 Test accuracy: 0.9798
# 195 Batch accuracy: 1.0 Test accuracy: 0.9798
# 196 Batch accuracy: 1.0 Test accuracy: 0.98
# 197 Batch accuracy: 1.0 Test accuracy: 0.9798
# 198 Batch accuracy: 1.0 Test accuracy: 0.9798
# 199 Batch accuracy: 1.0 Test accuracy: 0.9798
# 200 Batch accuracy: 1.0 Test accuracy: 0.98
# 201 Batch accuracy: 1.0 Test accuracy: 0.9796
# 202 Batch accuracy: 1.0 Test accuracy: 0.98
# 203 Batch accuracy: 1.0 Test accuracy: 0.98
# 204 Batch accuracy: 1.0 Test accuracy: 0.9798
# 205 Batch accuracy: 1.0 Test accuracy: 0.98
# 206 Batch accuracy: 1.0 Test accuracy: 0.9796
# 207 Batch accuracy: 1.0 Test accuracy: 0.98
# 208 Batch accuracy: 1.0 Test accuracy: 0.9796
# 209 Batch accuracy: 1.0 Test accuracy: 0.9796
# 210 Batch accuracy: 1.0 Test accuracy: 0.9796
# 211 Batch accuracy: 1.0 Test accuracy: 0.9798
# 212 Batch accuracy: 1.0 Test accuracy: 0.9798
# 213 Batch accuracy: 1.0 Test accuracy: 0.98
# 214 Batch accuracy: 1.0 Test accuracy: 0.9798
# 215 Batch accuracy: 1.0 Test accuracy: 0.9798
# 216 Batch accuracy: 1.0 Test accuracy: 0.9798
# 217 Batch accuracy: 1.0 Test accuracy: 0.98
# 218 Batch accuracy: 1.0 Test accuracy: 0.9796
# 219 Batch accuracy: 1.0 Test accuracy: 0.9798
# 220 Batch accuracy: 1.0 Test accuracy: 0.98
# 221 Batch accuracy: 1.0 Test accuracy: 0.98
# 222 Batch accuracy: 1.0 Test accuracy: 0.9796
# 223 Batch accuracy: 1.0 Test accuracy: 0.9798
# 224 Batch accuracy: 1.0 Test accuracy: 0.9796
# 225 Batch accuracy: 1.0 Test accuracy: 0.9802
# 226 Batch accuracy: 1.0 Test accuracy: 0.98
# 227 Batch accuracy: 1.0 Test accuracy: 0.9798
# 228 Batch accuracy: 1.0 Test accuracy: 0.9798
# 229 Batch accuracy: 1.0 Test accuracy: 0.9798
# 230 Batch accuracy: 1.0 Test accuracy: 0.98
# 231 Batch accuracy: 1.0 Test accuracy: 0.9802
# 232 Batch accuracy: 1.0 Test accuracy: 0.98
# 233 Batch accuracy: 1.0 Test accuracy: 0.9802
# 234 Batch accuracy: 1.0 Test accuracy: 0.9802
# 235 Batch accuracy: 1.0 Test accuracy: 0.9796
# 236 Batch accuracy: 1.0 Test accuracy: 0.9798
# 237 Batch accuracy: 1.0 Test accuracy: 0.98
# 238 Batch accuracy: 1.0 Test accuracy: 0.9798
# 239 Batch accuracy: 1.0 Test accuracy: 0.9798
# 240 Batch accuracy: 1.0 Test accuracy: 0.9796
# 241 Batch accuracy: 1.0 Test accuracy: 0.98
# 242 Batch accuracy: 1.0 Test accuracy: 0.9798
# 243 Batch accuracy: 1.0 Test accuracy: 0.9798
# 244 Batch accuracy: 1.0 Test accuracy: 0.9798
# 245 Batch accuracy: 1.0 Test accuracy: 0.9798
# 246 Batch accuracy: 1.0 Test accuracy: 0.98
# 247 Batch accuracy: 1.0 Test accuracy: 0.9798
# 248 Batch accuracy: 1.0 Test accuracy: 0.9798
# 249 Batch accuracy: 1.0 Test accuracy: 0.9796
# 250 Batch accuracy: 1.0 Test accuracy: 0.98
# 251 Batch accuracy: 1.0 Test accuracy: 0.98
# 252 Batch accuracy: 1.0 Test accuracy: 0.9798
# 253 Batch accuracy: 1.0 Test accuracy: 0.9798
# 254 Batch accuracy: 1.0 Test accuracy: 0.9798
# 255 Batch accuracy: 1.0 Test accuracy: 0.98
# 256 Batch accuracy: 1.0 Test accuracy: 0.9798
# 257 Batch accuracy: 1.0 Test accuracy: 0.9798
# 258 Batch accuracy: 1.0 Test accuracy: 0.98
# 259 Batch accuracy: 1.0 Test accuracy: 0.9798
# 260 Batch accuracy: 1.0 Test accuracy: 0.9798
# 261 Batch accuracy: 1.0 Test accuracy: 0.98
# 262 Batch accuracy: 1.0 Test accuracy: 0.9796
# 263 Batch accuracy: 1.0 Test accuracy: 0.98
# 264 Batch accuracy: 1.0 Test accuracy: 0.9802
# 265 Batch accuracy: 1.0 Test accuracy: 0.9798
# 266 Batch accuracy: 1.0 Test accuracy: 0.9798
# 267 Batch accuracy: 1.0 Test accuracy: 0.9802
# 268 Batch accuracy: 1.0 Test accuracy: 0.98
# 269 Batch accuracy: 1.0 Test accuracy: 0.9798
# 270 Batch accuracy: 1.0 Test accuracy: 0.9798
# 271 Batch accuracy: 1.0 Test accuracy: 0.9798
# 272 Batch accuracy: 1.0 Test accuracy: 0.98
# 273 Batch accuracy: 1.0 Test accuracy: 0.9798
# 274 Batch accuracy: 1.0 Test accuracy: 0.9796
# 275 Batch accuracy: 1.0 Test accuracy: 0.9798
# 276 Batch accuracy: 1.0 Test accuracy: 0.9798
# 277 Batch accuracy: 1.0 Test accuracy: 0.98
# 278 Batch accuracy: 1.0 Test accuracy: 0.9798
# 279 Batch accuracy: 1.0 Test accuracy: 0.98
# 280 Batch accuracy: 1.0 Test accuracy: 0.9798
# 281 Batch accuracy: 1.0 Test accuracy: 0.9802
# 282 Batch accuracy: 1.0 Test accuracy: 0.98
# 283 Batch accuracy: 1.0 Test accuracy: 0.9798
# 284 Batch accuracy: 1.0 Test accuracy: 0.9798
# 285 Batch accuracy: 1.0 Test accuracy: 0.9798
# 286 Batch accuracy: 1.0 Test accuracy: 0.9798
# 287 Batch accuracy: 1.0 Test accuracy: 0.9798
# 288 Batch accuracy: 1.0 Test accuracy: 0.9798
# 289 Batch accuracy: 1.0 Test accuracy: 0.98
# 290 Batch accuracy: 1.0 Test accuracy: 0.9798
# 291 Batch accuracy: 1.0 Test accuracy: 0.98
# 292 Batch accuracy: 1.0 Test accuracy: 0.9798
# 293 Batch accuracy: 1.0 Test accuracy: 0.9798
# 294 Batch accuracy: 1.0 Test accuracy: 0.9798
# 295 Batch accuracy: 1.0 Test accuracy: 0.98
# 296 Batch accuracy: 1.0 Test accuracy: 0.98
# 297 Batch accuracy: 1.0 Test accuracy: 0.98
# 298 Batch accuracy: 1.0 Test accuracy: 0.9798
# 299 Batch accuracy: 1.0 Test accuracy: 0.98
# 300 Batch accuracy: 1.0 Test accuracy: 0.98
# 301 Batch accuracy: 1.0 Test accuracy: 0.98
# 302 Batch accuracy: 1.0 Test accuracy: 0.98
# 303 Batch accuracy: 1.0 Test accuracy: 0.9798
# 304 Batch accuracy: 1.0 Test accuracy: 0.98
# 305 Batch accuracy: 1.0 Test accuracy: 0.98
# 306 Batch accuracy: 1.0 Test accuracy: 0.98
# 307 Batch accuracy: 1.0 Test accuracy: 0.9798
# 308 Batch accuracy: 1.0 Test accuracy: 0.9798
# 309 Batch accuracy: 1.0 Test accuracy: 0.9798
# 310 Batch accuracy: 1.0 Test accuracy: 0.9798
# 311 Batch accuracy: 1.0 Test accuracy: 0.9798
# 312 Batch accuracy: 1.0 Test accuracy: 0.9798
# 313 Batch accuracy: 1.0 Test accuracy: 0.9798
# 314 Batch accuracy: 1.0 Test accuracy: 0.98
# 315 Batch accuracy: 1.0 Test accuracy: 0.9802
# 316 Batch accuracy: 1.0 Test accuracy: 0.98
# 317 Batch accuracy: 1.0 Test accuracy: 0.98
# 318 Batch accuracy: 1.0 Test accuracy: 0.98
# 319 Batch accuracy: 1.0 Test accuracy: 0.9798
# 320 Batch accuracy: 1.0 Test accuracy: 0.98
# 321 Batch accuracy: 1.0 Test accuracy: 0.9798
# 322 Batch accuracy: 1.0 Test accuracy: 0.98
# 323 Batch accuracy: 1.0 Test accuracy: 0.9798
# 324 Batch accuracy: 1.0 Test accuracy: 0.98
# 325 Batch accuracy: 1.0 Test accuracy: 0.9798
# 326 Batch accuracy: 1.0 Test accuracy: 0.98
# 327 Batch accuracy: 1.0 Test accuracy: 0.9798
# 328 Batch accuracy: 1.0 Test accuracy: 0.98
# 329 Batch accuracy: 1.0 Test accuracy: 0.9802
# 330 Batch accuracy: 1.0 Test accuracy: 0.9802
# 331 Batch accuracy: 1.0 Test accuracy: 0.98
# 332 Batch accuracy: 1.0 Test accuracy: 0.98
# 333 Batch accuracy: 1.0 Test accuracy: 0.98
# 334 Batch accuracy: 1.0 Test accuracy: 0.98
# 335 Batch accuracy: 1.0 Test accuracy: 0.9798
# 336 Batch accuracy: 1.0 Test accuracy: 0.9802
# 337 Batch accuracy: 1.0 Test accuracy: 0.98
# 338 Batch accuracy: 1.0 Test accuracy: 0.9798
# 339 Batch accuracy: 1.0 Test accuracy: 0.98
# 340 Batch accuracy: 1.0 Test accuracy: 0.9798
# 341 Batch accuracy: 1.0 Test accuracy: 0.98
# 342 Batch accuracy: 1.0 Test accuracy: 0.98
# 343 Batch accuracy: 1.0 Test accuracy: 0.98
# 344 Batch accuracy: 1.0 Test accuracy: 0.98
# 345 Batch accuracy: 1.0 Test accuracy: 0.9798
# 346 Batch accuracy: 1.0 Test accuracy: 0.9798
# 347 Batch accuracy: 1.0 Test accuracy: 0.98
# 348 Batch accuracy: 1.0 Test accuracy: 0.98
# 349 Batch accuracy: 1.0 Test accuracy: 0.98
# 350 Batch accuracy: 1.0 Test accuracy: 0.9802
# 351 Batch accuracy: 1.0 Test accuracy: 0.9798
# 352 Batch accuracy: 1.0 Test accuracy: 0.98
# 353 Batch accuracy: 1.0 Test accuracy: 0.98
# 354 Batch accuracy: 1.0 Test accuracy: 0.9802
# 355 Batch accuracy: 1.0 Test accuracy: 0.98
# 356 Batch accuracy: 1.0 Test accuracy: 0.9798
# 357 Batch accuracy: 1.0 Test accuracy: 0.98
# 358 Batch accuracy: 1.0 Test accuracy: 0.98
# 359 Batch accuracy: 1.0 Test accuracy: 0.9798
# 360 Batch accuracy: 1.0 Test accuracy: 0.9804
# 361 Batch accuracy: 1.0 Test accuracy: 0.98
# 362 Batch accuracy: 1.0 Test accuracy: 0.9798
# 363 Batch accuracy: 1.0 Test accuracy: 0.98
# 364 Batch accuracy: 1.0 Test accuracy: 0.9802
# 365 Batch accuracy: 1.0 Test accuracy: 0.9802
# 366 Batch accuracy: 1.0 Test accuracy: 0.9802
# 367 Batch accuracy: 1.0 Test accuracy: 0.98
# 368 Batch accuracy: 1.0 Test accuracy: 0.98
# 369 Batch accuracy: 1.0 Test accuracy: 0.98
# 370 Batch accuracy: 1.0 Test accuracy: 0.98
# 371 Batch accuracy: 1.0 Test accuracy: 0.98
# 372 Batch accuracy: 1.0 Test accuracy: 0.98
# 373 Batch accuracy: 1.0 Test accuracy: 0.9798
# 374 Batch accuracy: 1.0 Test accuracy: 0.98
# 375 Batch accuracy: 1.0 Test accuracy: 0.9804
# 376 Batch accuracy: 1.0 Test accuracy: 0.9804
# 377 Batch accuracy: 1.0 Test accuracy: 0.9802
# 378 Batch accuracy: 1.0 Test accuracy: 0.98
# 379 Batch accuracy: 1.0 Test accuracy: 0.98
# 380 Batch accuracy: 1.0 Test accuracy: 0.98
# 381 Batch accuracy: 1.0 Test accuracy: 0.98
# 382 Batch accuracy: 1.0 Test accuracy: 0.98
# 383 Batch accuracy: 1.0 Test accuracy: 0.9798
# 384 Batch accuracy: 1.0 Test accuracy: 0.98
# 385 Batch accuracy: 1.0 Test accuracy: 0.9798
# 386 Batch accuracy: 1.0 Test accuracy: 0.98
# 387 Batch accuracy: 1.0 Test accuracy: 0.9798
# 388 Batch accuracy: 1.0 Test accuracy: 0.98
# 389 Batch accuracy: 1.0 Test accuracy: 0.98
# 390 Batch accuracy: 1.0 Test accuracy: 0.9798
# 391 Batch accuracy: 1.0 Test accuracy: 0.9802
# 392 Batch accuracy: 1.0 Test accuracy: 0.9802
# 393 Batch accuracy: 1.0 Test accuracy: 0.98
# 394 Batch accuracy: 1.0 Test accuracy: 0.98
# 395 Batch accuracy: 1.0 Test accuracy: 0.9802
# 396 Batch accuracy: 1.0 Test accuracy: 0.9798
# 397 Batch accuracy: 1.0 Test accuracy: 0.9802
# 398 Batch accuracy: 1.0 Test accuracy: 0.9804
# 399 Batch accuracy: 1.0 Test accuracy: 0.98

# %% [markdown]
# Now, we will use this trained neural network model to make predictions.

# %%
with tf.Session() as sess:
    saver.restore(sess, "./my_model_final.ckpt")    # loads the model parameters from the disk
    X_new_scaled = X_test[:30]                      # loads somenew images to be classified (feature scaled from 0 to 1)    
    Z = logits.eval(feed_dict = {X: X_new_scaled})  # evaluates the logits node
    y_pred = np.argmax(Z, axis = 1)         # class prediction by simply picking the class that has the highest logit value
# Out:
# INFO:tensorflow:Restoring parameters from ./my_model_final.ckpt

# %%
print("Actual classes:   ", y_test[:30])
print("Predicted classes:", y_pred)
# Out:
# Actual classes:    [7 2 1 0 4 1 4 9 5 9 0 6 9 0 1 5 9 7 3 4 9 6 6 5 4 0 7 4 0 1]
# Predicted classes: [7 2 1 0 4 1 4 9 5 9 0 6 9 0 1 5 9 7 3 4 9 6 6 5 4 0 7 4 0 1]
